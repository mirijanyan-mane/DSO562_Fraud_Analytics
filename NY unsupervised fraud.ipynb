# %% [markdown]
# # Unsupervised anomaly detection (fraud) algorithm
#
# This notebook has good example algorithms to do a forensic-type analysis, looking for anomalies in a dataset. We first do some data cleaning (exclusions, imputation), then build variables that are designed to look for the kinds of anomalies we are interested in, in this case, unusual property valuations.
#
# After we build the variables we know we have lots of correlations and too high dimensionality so we need to remove correlations and reduce dimensionality. Since we don't have a dependent variable the easiest useful thing to do is PCA. We z scale, do PCA, keep the top PCs, then z scale again in order to make each retained PC equally important (optional step).
#
# We use two different anamaly detection (fraud) algorithms. The first just looks for outliers in the final scaled PC space using a Minkowski distance from the origin. The second method makes a simple autoencoder and the fraud score is then the reproduction error. It's important to note that each/either of these two methods would be a fine fraud score by itself.
#
# Since we have two score and we don't really know which one is better we just average the two scores. To do this we replace the score with its rank order and then average the rank-ordered scores for our final score.
#
# Finally we sort all the records by this final score and explore the top n records. To help the investigation we show which of the variables are driving these top scoring records with a heat map of the variable zscores, which can point the investigators to what's making the high score for these top scoring records.
#
# This problem is an invented problem to demonstrate the process of building unsupervised fraud models. The data set is real and the invented problem is realistic. What's lacking the most is the ability to interact with domain experts in order to do proper exclusions and design good/appropriate variables.
#
# The data can be found here: https://data.cityofnewyork.us/Housing-Development/Property-Valuation-and-Assessment-Data/rgy2-tti8

# %%
from datetime import datetime
start_time = datetime.now()

# Load libraries
# %pip install openpyxl
# %pip install xlwt

from sklearn.neural_network import MLPRegressor
import pandas as pd
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
# %matplotlib inline

print('LOAD DURATION:',datetime.now() - start_time) # about 3 seconds
# Out:
# LOAD DURATION: 0:00:12.997225

# %%
# %%time
data = pd.read_csv('NY property data.csv')
NY_data_orig = data.copy()
data.shape
# Out:
# CPU times: user 3.39 s, sys: 681 ms, total: 4.07 s
# Wall time: 4.29 s
# (1070994, 32)

# %%
data.dtypes
# Out:
# RECORD        int64
# BBLE         object
# BORO          int64
# BLOCK         int64
# LOT           int64
# EASEMENT     object
# OWNER        object
# BLDGCL       object
# TAXCLASS     object
# LTFRONT       int64
# LTDEPTH       int64
# EXT          object
# STORIES     float64
# FULLVAL     float64
# AVLAND      float64
# AVTOT       float64
# EXLAND      float64
# EXTOT       float64
# EXCD1       float64
# STADDR       object
# ZIP         float64
# EXMPTCL      object
# BLDFRONT      int64
# BLDDEPTH      int64
# AVLAND2     float64
# AVTOT2      float64
# EXLAND2     float64
# EXTOT2      float64
# EXCD2       float64
# PERIOD       object
# YEAR         object
# VALTYPE      object
# dtype: object

# %%
data.head()
# Out:
#    RECORD        BBLE  BORO  BLOCK  LOT EASEMENT                  OWNER  \
# 0       1  1000010101     1      1  101      NaN  U S GOVT LAND & BLDGS
# 1       2  1000010201     1      1  201      NaN  U S GOVT LAND & BLDGS
# 2       3  1000020001     1      2    1      NaN  DEPT OF GENERAL SERVI
# 3       4  1000020023     1      2   23      NaN  DEPARTMENT OF BUSINES
# 4       5  1000030001     1      3    1      NaN   PARKS AND RECREATION
#
#   BLDGCL TAXCLASS  LTFRONT  ...  BLDFRONT BLDDEPTH      AVLAND2       AVTOT2  \
# 0     P7        4      500  ...         0        0    3775500.0    8613000.0
# 1     Z9        4       27  ...         0        0   11111400.0   80690400.0
# 2     Y7        4      709  ...       709      564   32321790.0   40179510.0
# 3     T2        4      793  ...        85      551   13644000.0   15750000.0
# 4     Q1        4      323  ...        89       57  106348680.0  107758350.0
#
#        EXLAND2       EXTOT2  EXCD2  PERIOD     YEAR VALTYPE
# 0    3775500.0    8613000.0    NaN   FINAL  2010/11   AC-TR
# 1   11111400.0   80690400.0    NaN   FINAL  2010/11   AC-TR
# 2   32321790.0   40179510.0    NaN   FINAL  2010/11   AC-TR
# 3   13644000.0   15750000.0    NaN   FINAL  2010/11   AC-TR
# 4  106348680.0  107758350.0    NaN   FINAL  2010/11   AC-TR
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Remove some benign properties that we aren't interested in
# There are certainly better ways to do this, and this important step can/should be improved.

# %%
# first look at the most frequent owners
remove_list = data['OWNER'].value_counts().head(20).index.tolist()
remove_list
# Out:
# ['PARKCHESTER PRESERVAT',
#  'PARKS AND RECREATION',
#  'DCAS',
#  'HOUSING PRESERVATION',
#  'CITY OF NEW YORK',
#  'DEPT OF ENVIRONMENTAL',
#  'BOARD OF EDUCATION',
#  'NEW YORK CITY HOUSING',
#  'CNY/NYCTA',
#  'NYC HOUSING PARTNERSH',
#  'YORKVILLE TOWERS ASSO',
#  'DEPARTMENT OF BUSINES',
#  'DEPT OF TRANSPORTATIO',
#  'MTA/LIRR',
#  'PARCKHESTER PRESERVAT',
#  'MH RESIDENTIAL 1, LLC',
#  '434 M LLC',
#  'LINCOLN PLAZA ASSOCIA',
#  'DEUTSCHE BANK NATIONA',
#  '561 11TH AVENUE TMG L']

# %%
# remove some of these and add some others to also be removed
remove_list.remove('YORKVILLE TOWERS ASSO')
remove_list.remove('434 M LLC')
remove_list.remove('DEUTSCHE BANK NATIONA')
remove_list.remove('561 11TH AVENUE TMG L')
remove_list.append('UNITED STATES OF AMER')
remove_list.append('U S GOVERNMENT OWNRD')
remove_list.append('THE CITY OF NEW YORK')
remove_list.append('NYS URBAN DEVELOPMENT')
remove_list.append('NYS DEPT OF ENVIRONME')
remove_list.append('CULTURAL AFFAIRS')
remove_list.append('DEPT OF GENERAL SERVI')
remove_list.append('DEPT RE-CITY OF NY')
remove_list
# Out:
# ['PARKCHESTER PRESERVAT',
#  'PARKS AND RECREATION',
#  'DCAS',
#  'HOUSING PRESERVATION',
#  'CITY OF NEW YORK',
#  'DEPT OF ENVIRONMENTAL',
#  'BOARD OF EDUCATION',
#  'NEW YORK CITY HOUSING',
#  'CNY/NYCTA',
#  'NYC HOUSING PARTNERSH',
#  'DEPARTMENT OF BUSINES',
#  'DEPT OF TRANSPORTATIO',
#  'MTA/LIRR',
#  'PARCKHESTER PRESERVAT',
#  'MH RESIDENTIAL 1, LLC',
#  'LINCOLN PLAZA ASSOCIA',
#  'UNITED STATES OF AMER',
#  'U S GOVERNMENT OWNRD',
#  'THE CITY OF NEW YORK',
#  'NYS URBAN DEVELOPMENT',
#  'NYS DEPT OF ENVIRONME',
#  'CULTURAL AFFAIRS',
#  'DEPT OF GENERAL SERVI',
#  'DEPT RE-CITY OF NY']

# %%
property_data = data[~data['OWNER'].isin(remove_list)].reset_index(drop=True)
property_data.shape
# Out:
# (1046826, 32)

# %%
data.shape
# Out:
# (1070994, 32)

# %%
# this is how many records we removed
len(data) - len(property_data)
# Out:
# 24168

# %%
numrecs = len(property_data)

# %% [markdown]
# ## Fill in missing ZIP

# %%
# How many zips are missing? Replace NAN with 0 and count them.
missing_zips = np.where(pd.isnull(property_data['ZIP']))[0]
len(missing_zips)
# Out:
# 21772

# %%
# Assume the data is already sorted by zip. If a zip is missing, 
# and the before and after zips are the same, fill in the zip with that value
for i in range(len(missing_zips)):
    if(property_data.loc[missing_zips[i]+1,'ZIP'] == property_data.loc[missing_zips[i]-1,'ZIP']):
        property_data.loc[missing_zips[i],'ZIP'] = property_data.loc[missing_zips[i]-1,'ZIP']

# %%
# How many are still left to fill in?
missing_zips = np.where(pd.isnull(property_data['ZIP']))[0]
len(missing_zips)
# Out:
# 10245

# %%
# For the remaining missing zips, just fill in with the previous record's zip.
for i in range(len(missing_zips)):
    property_data.loc[missing_zips[i],'ZIP'] = property_data.loc[missing_zips[i]-1,'ZIP']

# %%
missing_zips = np.where(pd.isnull(property_data['ZIP']))[0]
len(missing_zips)
# Out:
# 0

# %% [markdown]
# ## Calculate means for AVTOT, AVLAND, FULLVAL by taxclass, avoiding the records with zeros

# %%
property_data['FULLVAL'].replace('NaN',0)
temp =property_data[property_data['FULLVAL']!=0]
mean_fullval = temp.groupby('TAXCLASS')['FULLVAL'].mean()
print(mean_fullval)
# Out:
# TAXCLASS
# 1     5.700059e+05
# 1A    3.352942e+05
# 1B    3.738399e+05
# 1C    7.615359e+05
# 1D    2.233614e+07
# 2     8.005832e+05
# 2A    8.639066e+05
# 2B    1.254525e+06
# 2C    7.723493e+05
# 3     8.510005e+04
# 4     2.772747e+06
# Name: FULLVAL, dtype: float64

# %%
property_data['AVLAND'].replace('NaN',0)
temp_avland = property_data[property_data['AVLAND']!=0]
mean_avland = temp_avland.groupby('TAXCLASS')['AVLAND'].mean()

# %%
property_data['AVTOT'].replace('NaN',0)
temp_avtot = property_data[property_data['AVTOT']!=0]
mean_avtot = temp_avtot.groupby('TAXCLASS')['AVTOT'].mean()

# %% [markdown]
# ## Substituting decent values for AVTOT, AVLAND, FULLVAL from averages by taxclass

# %%
# %%time
for index in mean_fullval.index:
    property_data.loc[(property_data['FULLVAL']==0)&(property_data['TAXCLASS']==index),'FULLVAL']=mean_fullval[index]
    property_data.loc[(property_data['AVLAND']==0)&(property_data['TAXCLASS']==index),'AVLAND']=mean_avland[index]
    property_data.loc[(property_data['AVTOT']==0)&(property_data['TAXCLASS']==index),'AVTOT']=mean_avtot[index]
# Out:
# CPU times: user 2.03 s, sys: 68.6 ms, total: 2.1 s
# Wall time: 2.12 s

# %%
property_data.head().transpose()
# Out:
#                               0                      1                  2  \
# RECORD                        1                      2                  9
# BBLE                 1000010101             1000010201         1000041001
# BORO                          1                      1                  1
# BLOCK                         1                      1                  4
# LOT                         101                    201               1001
# EASEMENT                    NaN                    NaN                NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  TRZ HOLDINGS, LLC
# BLDGCL                       P7                     Z9                 R5
# TAXCLASS                      4                      4                  4
# LTFRONT                     500                     27                  0
# LTDEPTH                    1046                      0                  0
# EXT                         NaN                    NaN                NaN
# STORIES                     NaN                    NaN               50.0
# FULLVAL              21400000.0            193800000.0          3944762.0
# AVLAND                4225500.0             14310000.0           636093.0
# AVTOT                 9630000.0             87210000.0          1775143.0
# EXLAND                4225500.0             14310000.0                0.0
# EXTOT                 9630000.0             87210000.0                0.0
# EXCD1                    4600.0                 4600.0                NaN
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND     1 WATER STREET
# ZIP                     10004.0                10004.0            10004.0
# EXMPTCL                      X3                     X3                NaN
# BLDFRONT                      0                      0                  0
# BLDDEPTH                      0                      0                  0
# AVLAND2               3775500.0             11111400.0           636093.0
# AVTOT2                8613000.0             80690400.0          2049290.0
# EXLAND2               3775500.0             11111400.0                NaN
# EXTOT2                8613000.0             80690400.0                NaN
# EXCD2                       NaN                    NaN                NaN
# PERIOD                    FINAL                  FINAL              FINAL
# YEAR                    2010/11                2010/11            2010/11
# VALTYPE                   AC-TR                  AC-TR              AC-TR
#
#                           3                  4
# RECORD                   10                 11
# BBLE             1000041002         1000041003
# BORO                      1                  1
# BLOCK                     4                  4
# LOT                    1002               1003
# EASEMENT                NaN                NaN
# OWNER     TRZ HOLDINGS, LLC  TRZ HOLDINGS, LLC
# BLDGCL                   R5                 R5
# TAXCLASS                  4                  4
# LTFRONT                   0                  0
# LTDEPTH                   0                  0
# EXT                     NaN                NaN
# STORIES                50.0               50.0
# FULLVAL           5700930.0         10600000.0
# AVLAND             919276.0           967500.0
# AVTOT             2565419.0          4770000.0
# EXLAND                  0.0                0.0
# EXTOT                   0.0                0.0
# EXCD1                   NaN                NaN
# STADDR       1 WATER STREET     1 WATER STREET
# ZIP                 10004.0            10004.0
# EXMPTCL                 NaN                NaN
# BLDFRONT                  0                  0
# BLDDEPTH                  0                  0
# AVLAND2            919276.0           967500.0
# AVTOT2            2961617.0          5483912.0
# EXLAND2                 NaN                NaN
# EXTOT2                  NaN                NaN
# EXCD2                   NaN                NaN
# PERIOD                FINAL              FINAL
# YEAR                2010/11            2010/11
# VALTYPE               AC-TR              AC-TR

# %% [markdown]
# ## Fill in the missing STORIES

# %%
temp = property_data[property_data['STORIES'].isnull()]
len(temp)
# Out:
# 43968

# %%
temp['TAXCLASS'].value_counts()
# Out:
# 1B    19055
# 4     17979
# 2      3434
# 3      2416
# 1       877
# 2C      138
# 2B       34
# 2A       30
# 1A        5
# Name: TAXCLASS, dtype: int64

# %%
mean_stories = property_data.groupby('TAXCLASS')['STORIES'].mean()
print(mean_stories)
# Out:
# TAXCLASS
# 1      2.111633
# 1A     1.656867
# 1B     4.000000
# 1C     3.052748
# 1D     1.068966
# 2     16.310549
# 2A     2.844032
# 2B     4.001635
# 2C     4.744977
# 3      1.000000
# 4      5.517257
# Name: STORIES, dtype: float64

# %%
temp.head().transpose()
# Out:
#                              0                      1   \
# RECORD                        1                      2
# BBLE                 1000010101             1000010201
# BORO                          1                      1
# BLOCK                         1                      1
# LOT                         101                    201
# EASEMENT                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS
# BLDGCL                       P7                     Z9
# TAXCLASS                      4                      4
# LTFRONT                     500                     27
# LTDEPTH                    1046                      0
# EXT                         NaN                    NaN
# STORIES                     NaN                    NaN
# FULLVAL              21400000.0            193800000.0
# AVLAND                4225500.0             14310000.0
# AVTOT                 9630000.0             87210000.0
# EXLAND                4225500.0             14310000.0
# EXTOT                 9630000.0             87210000.0
# EXCD1                    4600.0                 4600.0
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND
# ZIP                     10004.0                10004.0
# EXMPTCL                      X3                     X3
# BLDFRONT                      0                      0
# BLDDEPTH                      0                      0
# AVLAND2               3775500.0             11111400.0
# AVTOT2                8613000.0             80690400.0
# EXLAND2               3775500.0             11111400.0
# EXTOT2                8613000.0             80690400.0
# EXCD2                       NaN                    NaN
# PERIOD                    FINAL                  FINAL
# YEAR                    2010/11                2010/11
# VALTYPE                   AC-TR                  AC-TR
#
#                               59                      60  \
# RECORD                        66                      67
# BBLE                  1000051004              1000051005
# BORO                           1                       1
# BLOCK                          5                       5
# LOT                         1004                    1005
# EASEMENT                     NaN                     NaN
# OWNER       SLG BROAD STREET 125   AMERICAN CIVIL LIBERT
# BLDGCL                        R5                      R5
# TAXCLASS                       4                       4
# LTFRONT                        0                       0
# LTDEPTH                        0                       0
# EXT                          NaN                     NaN
# STORIES                      NaN                     NaN
# FULLVAL                5266800.0               5266800.0
# AVLAND                  858211.0                858211.0
# AVTOT                  2370060.0               2370060.0
# EXLAND                  858211.0                858211.0
# EXTOT                  2370060.0               2370060.0
# EXCD1                     1501.0                  1501.0
# STADDR    2 AMERICAN EXPRESS PLZ  2 AMERICAN EXPRESS PLZ
# ZIP                      10004.0                 10004.0
# EXMPTCL                      NaN                     NaN
# BLDFRONT                       0                       0
# BLDDEPTH                       0                       0
# AVLAND2                 856725.0                856725.0
# AVTOT2                 2025271.0               2025271.0
# EXLAND2                 856725.0                856725.0
# EXTOT2                 2025271.0               2025271.0
# EXCD2                        NaN                     NaN
# PERIOD                     FINAL                   FINAL
# YEAR                     2010/11                 2010/11
# VALTYPE                    AC-TR                   AC-TR
#
#                               61
# RECORD                        68
# BBLE                  1000051006
# BORO                           1
# BLOCK                          5
# LOT                         1006
# EASEMENT                     NaN
# OWNER       SLG BROAD STREET 125
# BLDGCL                        R5
# TAXCLASS                       4
# LTFRONT                        0
# LTDEPTH                        0
# EXT                          NaN
# STORIES                      NaN
# FULLVAL                5168000.0
# AVLAND                  842112.0
# AVTOT                  2325600.0
# EXLAND                  842112.0
# EXTOT                  2325600.0
# EXCD1                     1505.0
# STADDR    2 AMERICAN EXPRESS PLZ
# ZIP                      10004.0
# EXMPTCL                      NaN
# BLDFRONT                       0
# BLDDEPTH                       0
# AVLAND2                 842112.0
# AVTOT2                 1987776.0
# EXLAND2                 842112.0
# EXTOT2                 1987776.0
# EXCD2                        NaN
# PERIOD                     FINAL
# YEAR                     2010/11
# VALTYPE                    AC-TR

# %%
len(property_data[property_data["STORIES"]==0])
# Out:
# 0

# %%
property_data['STORIES']=property_data['STORIES'].fillna(value =0)
for index in mean_stories.index:
    property_data.loc[(property_data['STORIES']==0)&(property_data['TAXCLASS']==index),'STORIES']=mean_stories[index]

# %%
property_data.head().transpose()
# Out:
#                               0                      1                  2  \
# RECORD                        1                      2                  9
# BBLE                 1000010101             1000010201         1000041001
# BORO                          1                      1                  1
# BLOCK                         1                      1                  4
# LOT                         101                    201               1001
# EASEMENT                    NaN                    NaN                NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  TRZ HOLDINGS, LLC
# BLDGCL                       P7                     Z9                 R5
# TAXCLASS                      4                      4                  4
# LTFRONT                     500                     27                  0
# LTDEPTH                    1046                      0                  0
# EXT                         NaN                    NaN                NaN
# STORIES                5.517257               5.517257               50.0
# FULLVAL              21400000.0            193800000.0          3944762.0
# AVLAND                4225500.0             14310000.0           636093.0
# AVTOT                 9630000.0             87210000.0          1775143.0
# EXLAND                4225500.0             14310000.0                0.0
# EXTOT                 9630000.0             87210000.0                0.0
# EXCD1                    4600.0                 4600.0                NaN
# STADDR         1 LIBERTY ISLAND         1 ELLIS ISLAND     1 WATER STREET
# ZIP                     10004.0                10004.0            10004.0
# EXMPTCL                      X3                     X3                NaN
# BLDFRONT                      0                      0                  0
# BLDDEPTH                      0                      0                  0
# AVLAND2               3775500.0             11111400.0           636093.0
# AVTOT2                8613000.0             80690400.0          2049290.0
# EXLAND2               3775500.0             11111400.0                NaN
# EXTOT2                8613000.0             80690400.0                NaN
# EXCD2                       NaN                    NaN                NaN
# PERIOD                    FINAL                  FINAL              FINAL
# YEAR                    2010/11                2010/11            2010/11
# VALTYPE                   AC-TR                  AC-TR              AC-TR
#
#                           3                  4
# RECORD                   10                 11
# BBLE             1000041002         1000041003
# BORO                      1                  1
# BLOCK                     4                  4
# LOT                    1002               1003
# EASEMENT                NaN                NaN
# OWNER     TRZ HOLDINGS, LLC  TRZ HOLDINGS, LLC
# BLDGCL                   R5                 R5
# TAXCLASS                  4                  4
# LTFRONT                   0                  0
# LTDEPTH                   0                  0
# EXT                     NaN                NaN
# STORIES                50.0               50.0
# FULLVAL           5700930.0         10600000.0
# AVLAND             919276.0           967500.0
# AVTOT             2565419.0          4770000.0
# EXLAND                  0.0                0.0
# EXTOT                   0.0                0.0
# EXCD1                   NaN                NaN
# STADDR       1 WATER STREET     1 WATER STREET
# ZIP                 10004.0            10004.0
# EXMPTCL                 NaN                NaN
# BLDFRONT                  0                  0
# BLDDEPTH                  0                  0
# AVLAND2            919276.0           967500.0
# AVTOT2            2961617.0          5483912.0
# EXLAND2                 NaN                NaN
# EXTOT2                  NaN                NaN
# EXCD2                   NaN                NaN
# PERIOD                FINAL              FINAL
# YEAR                2010/11            2010/11
# VALTYPE               AC-TR              AC-TR

# %% [markdown]
# ## Fill in LTFRONT, LTDEPTH, BLDDEPTH, BLDFRONT with averages by TAXCLASS

# %%
# Because these 4 fields do not have NAs, we just need to replace 0s. 
# We think zero and 1 are invalid values for these fields, so replace them wiht NA.
# Calculate groupwise average. Replace 0 and 1's by NAs so they are not counted in calculating mean.
property_data.loc[property_data['LTFRONT']==0,'LTFRONT']=np.nan
property_data.loc[property_data['LTDEPTH']==0,'LTDEPTH']=np.nan
property_data.loc[property_data['BLDFRONT']==0,'BLDFRONT']=np.nan
property_data.loc[property_data['BLDDEPTH']==0,'BLDDEPTH']=np.nan
property_data.loc[property_data['LTFRONT']==1,'LTFRONT']=np.nan
property_data.loc[property_data['LTDEPTH']==1,'LTDEPTH']=np.nan
property_data.loc[property_data['BLDFRONT']==1,'BLDFRONT']=np.nan
property_data.loc[property_data['BLDDEPTH']==1,'BLDDEPTH']=np.nan

# Calculate mean now (mean function ignores NAs but not 0s hence we converted 0 to NA)
mean_LTFRONT=property_data.groupby(property_data['TAXCLASS'])['LTFRONT'].mean()
mean_LTDEPTH=property_data.groupby(property_data['TAXCLASS'])['LTDEPTH'].mean()
mean_BLDFRONT=property_data.groupby(property_data['TAXCLASS'])['BLDFRONT'].mean()
mean_BLDDEPTH=property_data.groupby(property_data['TAXCLASS'])['BLDDEPTH'].mean()

# Now impute values with the average for that record's TAXCLASS
for index in mean_LTFRONT.index:
    property_data.loc[(property_data['LTFRONT'].isnull())&(property_data['TAXCLASS']==index),'LTFRONT']=mean_LTFRONT[index]    
    property_data.loc[(property_data['LTDEPTH'].isnull())&(property_data['TAXCLASS']==index),'LTDEPTH']=mean_LTDEPTH[index]
    property_data.loc[(property_data['BLDFRONT'].isnull())&(property_data['TAXCLASS']==index),'BLDFRONT']=mean_BLDFRONT[index]
    property_data.loc[(property_data['BLDDEPTH'].isnull())&(property_data['TAXCLASS']==index),'BLDDEPTH']=mean_BLDDEPTH[index]

# %%
mean_LTFRONT
# Out:
# TAXCLASS
# 1      30.939210
# 1A     51.130890
# 1B     46.316982
# 1C     27.250825
# 1D    338.275862
# 2     111.579150
# 2A     25.919459
# 2B     27.254800
# 2C     29.988866
# 3     154.473171
# 4      82.296384
# Name: LTFRONT, dtype: float64

# %%
mean_LTDEPTH
# Out:
# TAXCLASS
# 1      99.279091
# 1A     90.095778
# 1B    103.993512
# 1C     96.778878
# 1D    497.827586
# 2     130.815876
# 2A     97.288381
# 2B     95.725639
# 2C     95.748523
# 3     274.124729
# 4     124.443774
# Name: LTDEPTH, dtype: float64

# %%
mean_BLDFRONT
# Out:
# TAXCLASS
# 1     21.403255
# 1A    25.026348
# 1B    39.500000
# 1C    23.367589
# 1D    19.586207
# 2     91.495779
# 2A    22.985669
# 2B    26.033148
# 2C    27.887084
# 3     10.000000
# 4     62.082133
# Name: BLDFRONT, dtype: float64

# %%
mean_BLDDEPTH
# Out:
# TAXCLASS
# 1      41.560577
# 1A     44.952387
# 1B     82.666667
# 1C     60.094862
# 1D     36.862069
# 2     104.282570
# 2A     62.435640
# 2B     66.521339
# 2C     68.657523
# 3      17.500000
# 4      86.296710
# Name: BLDDEPTH, dtype: float64

# %%
data = property_data.copy()
data.shape
# Out:
# (1046826, 32)

# %%
data.dtypes
# Out:
# RECORD        int64
# BBLE         object
# BORO          int64
# BLOCK         int64
# LOT           int64
# EASEMENT     object
# OWNER        object
# BLDGCL       object
# TAXCLASS     object
# LTFRONT     float64
# LTDEPTH     float64
# EXT          object
# STORIES     float64
# FULLVAL     float64
# AVLAND      float64
# AVTOT       float64
# EXLAND      float64
# EXTOT       float64
# EXCD1       float64
# STADDR       object
# ZIP         float64
# EXMPTCL      object
# BLDFRONT    float64
# BLDDEPTH    float64
# AVLAND2     float64
# AVTOT2      float64
# EXLAND2     float64
# EXTOT2      float64
# EXCD2       float64
# PERIOD       object
# YEAR         object
# VALTYPE      object
# dtype: object

# %%
# convert ZIP to a string rather than a float
# We call the first three digits of the zip zip3
data['ZIP'] = data['ZIP'].astype(str)
data['zip3'] = data['ZIP'].str[:3]

# %%
data.count()
# Out:
# RECORD      1046826
# BBLE        1046826
# BORO        1046826
# BLOCK       1046826
# LOT         1046826
# EASEMENT       2967
# OWNER       1015081
# BLDGCL      1046826
# TAXCLASS    1046826
# LTFRONT     1046826
# LTDEPTH     1046826
# EXT          353372
# STORIES     1046826
# FULLVAL     1046826
# AVLAND      1046826
# AVTOT       1046826
# EXLAND      1046826
# EXTOT       1046826
# EXCD1        625308
# STADDR      1046357
# ZIP         1046826
# EXMPTCL       10681
# BLDFRONT    1046826
# BLDDEPTH    1046826
# AVLAND2      267417
# AVTOT2       267423
# EXLAND2       82371
# EXTOT2       119371
# EXCD2         92912
# PERIOD      1046826
# YEAR        1046826
# VALTYPE     1046826
# zip3        1046826
# dtype: int64

# %%
cols = data.columns
print(cols)
# Out:
# Index(['RECORD', 'BBLE', 'BORO', 'BLOCK', 'LOT', 'EASEMENT', 'OWNER', 'BLDGCL',
#        'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES', 'FULLVAL', 'AVLAND',
#        'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR', 'ZIP', 'EXMPTCL',
#        'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2',
#        'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE', 'zip3'],
#       dtype='object')

# %% [markdown]
# ### Now build the variables

# %%
data['ltsize'] = data['LTFRONT'] * data['LTDEPTH']
data['bldsize'] = data['BLDFRONT'] * data['BLDDEPTH']
data['bldvol'] = data['bldsize'] * data['STORIES']

# %%
data['r1'] = data['FULLVAL'] / data['ltsize']
data['r2'] = data['FULLVAL'] / data['bldsize']
data['r3'] = data['FULLVAL'] / data['bldvol']
data['r4'] = data['AVLAND'] / data['ltsize']
data['r5'] = data['AVLAND'] / data['bldsize']
data['r6'] = data['AVLAND'] / data['bldvol']
data['r7'] = data['AVTOT'] / data['ltsize']
data['r8'] = data['AVTOT'] / data['bldsize']
data['r9'] = data['AVTOT'] / data['bldvol']

# %%
# add in the inverse of all the 9 primary variables
for col in data.columns[36:]:
    data[col+'inv'] = 1/(data[col])

# %%
vars18 = ['r1','r2','r3','r4','r5','r6','r7','r8','r9',
          'r1inv','r2inv','r3inv','r4inv','r5inv','r6inv','r7inv','r8inv','r9inv']
zip5_mean = data.groupby('ZIP')[vars18].mean()
zip3_mean = data.groupby('zip3')[vars18].mean()
taxclass_mean = data.groupby('TAXCLASS')[vars18].mean()
borough_mean = data.groupby('BORO')[vars18].mean()
data = data.join(zip5_mean, on='ZIP', rsuffix='_zip5')
data = data.join(zip3_mean, on='zip3', rsuffix='_zip3')
data = data.join(taxclass_mean, on='TAXCLASS', rsuffix='_taxclass')
data = data.join(borough_mean, on='BORO', rsuffix='_boro')
rsuffix = ['_zip5', '_zip3', '_taxclass', '_boro']
for var in vars18:
    for r in rsuffix:
        data[str(var)+r] = data[var] / data[str(var)+r]

# %%
data.head().transpose()
# Out:
#                      0           1           2           3           4
# RECORD               1           2           9          10          11
# BBLE        1000010101  1000010201  1000041001  1000041002  1000041003
# BORO                 1           1           1           1           1
# BLOCK                1           1           4           4           4
# LOT                101         201        1001        1002        1003
# ...                ...         ...         ...         ...         ...
# r5inv_boro    0.000569    0.000168    0.003782    0.002617    0.002487
# r6inv_boro    0.000147    0.000043     0.00883     0.00611    0.005805
# r7inv_boro    0.106805    0.000076    0.011346    0.007851    0.004222
# r8inv_boro    0.001731    0.000191    0.009388    0.006496    0.003494
# r9inv_boro    0.000459    0.000051    0.022555    0.015607    0.008394
#
# [126 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['RECORD', 'BBLE', 'BORO', 'BLOCK', 'LOT', 'EASEMENT', 'OWNER', 'BLDGCL',
#        'TAXCLASS', 'LTFRONT',
#        ...
#        'r9_boro', 'r1inv_boro', 'r2inv_boro', 'r3inv_boro', 'r4inv_boro',
#        'r5inv_boro', 'r6inv_boro', 'r7inv_boro', 'r8inv_boro', 'r9inv_boro'],
#       dtype='object', length=126)

# %%
save_record = data['RECORD']
save_record.head()
# Out:
# 0     1
# 1     2
# 2     9
# 3    10
# 4    11
# Name: RECORD, dtype: int64

# %%
dropcols = ['RECORD','BBLE', 'BORO', 'BLOCK', 'LOT', 'EASEMENT',
       'OWNER', 'BLDGCL', 'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES',
       'FULLVAL', 'AVLAND', 'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR',
       'ZIP', 'EXMPTCL', 'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2',
       'EXLAND2', 'EXTOT2', 'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE', 'zip3','ltsize','bldsize','bldvol']
data = data.drop(columns = dropcols)
data.shape
# Out:
# (1046826, 90)

# %%
data.head().transpose()
# Out:
#                       0             1           2            3            4
# r1            40.917782  57678.882190  385.182796   556.662267  1035.027624
# r2          3994.412456  36173.697854  736.308714  1064.105879  1978.540749
# r3           723.985188   6556.463990   14.726174    21.282118    39.570815
# r4             8.079350   4258.951518   62.110738    89.761892    94.470682
# r5           788.709805   2671.030012  118.729804   171.587267   180.588507
# ...                 ...           ...         ...          ...          ...
# r5inv_boro     0.000569      0.000168    0.003782     0.002617     0.002487
# r6inv_boro     0.000147      0.000043    0.008830     0.006110     0.005805
# r7inv_boro     0.106805      0.000076    0.011346     0.007851     0.004222
# r8inv_boro     0.001731      0.000191    0.009388     0.006496     0.003494
# r9inv_boro     0.000459      0.000051    0.022555     0.015607     0.008394
#
# [90 rows x 5 columns]

# %%
# Calculate and write the basic statistics of all the variables to check if everything looks OK
stats = data.describe().transpose()
stats.to_excel('stats_on_vars.xlsx')

# %%
# data.to_csv('NY vars.csv', index=False)
data.describe()
# Out:
#                  r1            r2            r3            r4            r5  \
# count  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06
# mean   2.135691e+02  5.364155e+02  2.440821e+02  1.046467e+01  2.281677e+01
# std    5.325639e+02  1.027443e+03  4.988230e+02  6.997586e+01  3.785065e+02
# min    3.905765e-04  7.466192e-04  8.983394e-05  8.333333e-06  2.096125e-04
# 25%    7.626263e+01  2.118164e+02  8.250000e+01  2.354081e+00  6.204263e+00
# 50%    1.528571e+02  5.000000e+02  2.390625e+02  4.596931e+00  1.498098e+01
# 75%    2.431818e+02  6.838235e+02  3.362314e+02  7.225445e+00  2.028646e+01
# max    1.386373e+05  3.105516e+05  2.275000e+05  2.224980e+04  3.346364e+05
#
#                  r6            r7            r8            r9         r1inv  \
# count  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06
# mean   1.004138e+01  2.683329e+01  5.046225e+01  1.907402e+01  1.131511e-01
# std    1.783286e+02  2.038739e+02  9.322000e+02  3.270238e+02  5.806045e+00
# min    1.038033e-05  8.333333e-06  3.062474e-04  6.049251e-05  7.213064e-06
# 25%    2.015872e+00  5.281000e+00  1.746754e+01  7.089338e+00  4.112150e-03
# 50%    7.146888e+00  8.579254e+00  2.697736e+01  1.267829e+01  6.542056e-03
# 75%    1.004363e+01  1.352700e+01  3.600000e+01  1.757576e+01  1.311258e-02
# max    1.115455e+05  6.471185e+04  8.713622e+05  2.904541e+05  2.560318e+03
#
#        ...       r9_boro    r1inv_boro    r2inv_boro    r3inv_boro  \
# count  ...  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06
# mean   ...  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# std    ...  1.572688e+01  5.725092e+01  4.466163e+01  4.778748e+01
# min    ...  2.777226e-06  3.022904e-05  3.164322e-05  3.083654e-06
# 25%    ...  3.906492e-01  4.793202e-02  2.866668e-02  6.645456e-03
# 50%    ...  6.729240e-01  7.304364e-02  4.186098e-02  1.070110e-02
# 75%    ...  9.393327e-01  1.399090e-01  8.763088e-02  2.546326e-02
# max    ...  1.381933e+04  3.571187e+04  3.279601e+04  3.711074e+04
#
#          r4inv_boro    r5inv_boro    r6inv_boro    r7inv_boro    r8inv_boro  \
# count  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06
# mean   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# std    5.090181e+01  1.959085e+01  2.941052e+01  6.264512e+01  2.475668e+01
# min    1.382444e-05  4.150239e-06  4.480255e-07  9.526489e-06  4.229670e-06
# 25%    8.307361e-02  5.733016e-02  1.350440e-02  1.464240e-01  8.238668e-02
# 50%    1.409591e-01  7.915880e-02  2.405543e-02  2.982497e-01  1.267765e-01
# 75%    2.591898e-01  1.497378e-01  5.473397e-02  4.890672e-01  2.054876e-01
# max    4.817898e+04  3.428855e+03  3.095585e+03  5.918176e+04  1.379716e+04
#
#          r9inv_boro
# count  1.046826e+06
# mean   1.000000e+00
# std    2.160514e+01
# min    2.655153e-06
# 25%    3.214915e-02
# 50%    5.180770e-02
# 75%    8.663041e-02
# max    1.030168e+04
#
# [8 rows x 90 columns]

# %%
# zscale all the variables
data_zs = (data - data.mean()) / data.std()
data_zs_save = data_zs.copy()
data_zs.describe()
# Out:
#                  r1            r2            r3            r4            r5  \
# count  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06
# mean   8.123390e-17  1.762059e-16 -4.327768e-17  1.357518e-17  2.612883e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -4.010199e-01 -5.220872e-01 -4.893158e-01 -1.495467e-01 -6.028049e-02
# 25%   -2.578217e-01 -3.159291e-01 -3.239267e-01 -1.159055e-01 -4.388961e-02
# 50%   -1.139995e-01 -3.544288e-02 -1.006284e-02 -8.385372e-02 -2.070184e-02
# 75%    5.560400e-02  1.434707e-01  1.847335e-01 -4.629056e-02 -6.684979e-03
# max    2.599196e+02  3.017347e+02  4.555842e+02  3.178144e+02  8.840365e+02
#
#                  r6            r7            r8            r9         r1inv  \
# count  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06
# mean   4.516463e-17  6.950494e-18  3.555340e-17  6.753654e-19 -2.715037e-20
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -5.630825e-02 -1.316171e-01 -5.413210e-02 -5.832592e-02 -1.948726e-02
# 25%   -4.500406e-02 -1.057139e-01 -3.539445e-02 -3.664775e-02 -1.878025e-02
# 50%   -1.623124e-02 -8.953595e-02 -2.519297e-02 -1.955740e-02 -1.836174e-02
# 75%    1.259701e-05 -6.526729e-02 -1.551410e-02 -4.581517e-03 -1.723007e-02
# max    6.254489e+02  3.172796e+02  9.346833e+02  8.881159e+02  4.409551e+02
#
#        ...       r9_boro    r1inv_boro    r2inv_boro    r3inv_boro  \
# count  ...  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06
# mean   ... -1.149818e-17 -3.631362e-18 -4.181156e-18  4.832765e-18
# std    ...  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min    ... -6.358523e-02 -1.746644e-02 -2.238987e-02 -2.092592e-02
# 25%    ... -3.874582e-02 -1.662974e-02 -2.174872e-02 -2.078692e-02
# 50%    ... -2.079726e-02 -1.619112e-02 -2.145329e-02 -2.070205e-02
# 75%    ... -3.857554e-03 -1.502318e-02 -2.042848e-02 -2.039314e-02
# max    ...  8.786441e+02  6.237607e+02  7.342993e+02  7.765578e+02
#
#          r4inv_boro    r5inv_boro    r6inv_boro    r7inv_boro    r8inv_boro  \
# count  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06
# mean  -4.045405e-18  4.887066e-19  1.357518e-19  1.975189e-18 -1.791924e-18
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.964540e-02 -5.104402e-02 -3.400143e-02 -1.596278e-02 -4.039296e-02
# 25%   -1.801363e-02 -4.811786e-02 -3.354228e-02 -1.362558e-02 -3.706528e-02
# 50%   -1.687643e-02 -4.700363e-02 -3.318353e-02 -1.120199e-02 -3.527223e-02
# 75%   -1.455371e-02 -4.340098e-02 -3.214041e-02 -8.155987e-03 -3.209285e-02
# max    9.464886e+02  1.749722e+02  1.052204e+02  9.446987e+02  5.572700e+02
#
#          r9inv_boro
# count  1.046826e+06
# mean   1.520421e-18
# std    1.000000e+00
# min   -4.628516e-02
# 25%   -4.479725e-02
# 50%   -4.388735e-02
# 75%   -4.227557e-02
# max    4.767697e+02
#
# [8 rows x 90 columns]

# %%
# %%time
# do a PCA and look at the cumulative variance plot
pca = PCA(n_components = .99, svd_solver = 'full')
pca.fit(data_zs)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components minus 1')
plt.ylabel('Cumulative explained variance')
plt.yticks(np.arange(0.05, 1.1, step=.1))
plt.xticks(np.arange(0, 36, step=2))
plt.axvline(x=6, linestyle='--')
plt.ylim(0,1)
# Out:
# CPU times: user 40 s, sys: 6.4 s, total: 46.4 s
# Wall time: 19 s
# (0.0, 1.0)

# %%
plt.plot(pca.explained_variance_ratio_)
plt.xlabel('Number of components minus 1')
plt.ylabel('PC variance')
plt.xticks(np.arange(0, 36, step=2))
plt.axvline(x=6, linestyle='--')

# %%
# %%time
# now redo the PCA but just keep the top few PCs
data_zs = data_zs_save.copy()
pca = PCA(n_components = 7, svd_solver = 'full')
princ_comps = pca.fit_transform(data_zs)
pca.n_components_
# Out:
# CPU times: user 40.2 s, sys: 6.95 s, total: 47.2 s
# Wall time: 18.7 s
# 7

# %%
print(np.cumsum(pca.explained_variance_ratio_))
# Out:
# [0.21987302 0.42074554 0.54728944 0.62168858 0.68089473 0.73854881
#  0.79441562]

# %%
data_pca = pd.DataFrame(princ_comps, columns = ['PC' + str(i) for i in range(1, pca.n_components_+1)])
data_pca.shape
# Out:
# (1046826, 7)

# %%
data_pca.head(5)
# Out:
#           PC1       PC2         PC3       PC4       PC5        PC6        PC7
# 0    7.812986  0.782459   -1.692937  0.098349  0.809687  -4.945516   2.719589
# 1  118.084854  9.786138  199.378118  0.399513  6.409308 -47.300143  27.856300
# 2    0.236833 -0.261303    0.707700  0.005826  0.003594   0.316049  -0.160373
# 3    0.834013 -0.204194    1.435032  0.008552  0.035698   0.083755  -0.026838
# 4    2.085611 -0.089649    2.951878  0.020970  0.159003  -0.774737   0.453820

# %%
data_pca.describe()
# Out:
#                 PC1           PC2           PC3           PC4           PC5  \
# count  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06
# mean   1.088730e-17 -3.909653e-18 -6.733291e-18 -4.344059e-19  1.547571e-18
# std    4.448435e+00  4.251885e+00  3.374752e+00  2.587648e+00  2.308366e+00
# min   -2.293067e+02 -3.645505e-01 -7.664554e+02 -7.165028e+02 -7.013362e+02
# 25%   -4.607729e-01 -2.158022e-01 -5.202718e-01 -6.543507e-03 -4.904047e-02
# 50%   -7.852356e-02 -1.900084e-01 -2.034711e-01  6.802326e-03  2.332644e-02
# 75%    1.745691e-01 -1.520397e-01  1.047161e-01  2.419782e-02  7.298279e-02
# max    3.036422e+03  1.683254e+03  1.093464e+03  2.126744e+03  1.020287e+03
#
#                 PC6           PC7
# count  1.046826e+06  1.046826e+06
# mean   3.230894e-18  3.583848e-18
# std    2.277909e+00  2.242323e+00
# min   -5.260210e+02 -7.315593e+02
# 25%   -3.033607e-01 -2.874438e-01
# 50%   -4.028889e-02 -6.883125e-02
# 75%    6.243616e-01  8.824867e-02
# max    1.181004e+03  7.825028e+02

# %%
# zscale the pcs
data_pca_zs = (data_pca - data_pca.mean()) / data_pca.std()
data_pca_zs.describe()
# Out:
#                 PC1           PC2           PC3           PC4           PC5  \
# count  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06
# mean   3.733175e-19 -1.629022e-18  2.226330e-18  9.774132e-19  2.776125e-18
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -5.154774e+01 -8.573855e-02 -2.271146e+02 -2.768935e+02 -3.038236e+02
# 25%   -1.035809e-01 -5.075447e-02 -1.541659e-01 -2.528747e-03 -2.124467e-02
# 50%   -1.765195e-02 -4.468804e-02 -6.029215e-02  2.628768e-03  1.010517e-02
# 75%    3.924282e-02 -3.575819e-02  3.102926e-02  9.351279e-03  3.161665e-02
# max    6.825822e+02  3.958843e+02  3.240133e+02  8.218831e+02  4.419954e+02
#
#                 PC6           PC7
# count  1.046826e+06  1.046826e+06
# mean  -1.981977e-18  1.221766e-18
# std    1.000000e+00  1.000000e+00
# min   -2.309228e+02 -3.262506e+02
# 25%   -1.331751e-01 -1.281902e-01
# 50%   -1.768679e-02 -3.069640e-02
# 75%    2.740942e-01  3.935591e-02
# max    5.184597e+02  3.489697e+02

# %%
data_pca_zs.shape
# Out:
# (1046826, 7)

# %%
data_pca_zs.head(5)
# Out:
#          PC1       PC2        PC3       PC4       PC5        PC6        PC7
# 0   1.756345  0.184026  -0.501648  0.038007  0.350762  -2.171078   1.212844
# 1  26.545259  2.301600  59.079339  0.154392  2.776556 -20.764725  12.422965
# 2   0.053240 -0.061456   0.209704  0.002252  0.001557   0.138745  -0.071521
# 3   0.187485 -0.048024   0.425226  0.003305  0.015465   0.036769  -0.011969
# 4   0.468842 -0.021084   0.874695  0.008104  0.068881  -0.340109   0.202388

# %% [markdown]
# ## Now calculate two unsupervised fraud scores

# %%
# Set the powers for the two Minkowski distance. the final resulrts are relatively insensitive to these choices. 
# Good choices are anywhere from 1 to about 4.
p1 = 2
p2 = 2
ntop = 1000

# %% [markdown]
# ### calculate score 1

# %%
oop1 = 1/p1
score1 = (((data_pca_zs).abs()**p1).sum(axis=1))**oop1
score1.head(10)
# Out:
# 0     3.111159
# 1    69.235492
# 2     0.273789
# 3     0.469062
# 4     1.070884
# 5     0.428559
# 6     0.284815
# 7     0.295393
# 8     0.764182
# 9     0.733115
# dtype: float64

# %%
score1.max()
# Out:
# 940.8780022137746

# %%
plt.hist(score1, bins =100, range=(0,1000))
plt.yscale('log')
plt.ylim(ymin=.1)
# Out:
# (0.1, 2089567.4539268154)

# %% [markdown]
# ### Autoencoder for score 2

# %%
NNmodel = MLPRegressor(hidden_layer_sizes=(10),activation='relu',verbose=True,max_iter=15, random_state=1)
NNmodel.fit(data_pca_zs,data_pca_zs)
# Out:
# Iteration 1, loss = 0.31203909
# Iteration 2, loss = 0.15880255
# Iteration 3, loss = 0.10783790
# Iteration 4, loss = 0.08697483
# Iteration 5, loss = 0.05928352
# Iteration 6, loss = 0.03834116
# Iteration 7, loss = 0.02695220
# Iteration 8, loss = 0.01765546
# Iteration 9, loss = 0.01269320
# Iteration 10, loss = 0.00949307
# Iteration 11, loss = 0.00595564
# Iteration 12, loss = 0.00330296
# Iteration 13, loss = 0.00309626
# Iteration 14, loss = 0.00168802
# Iteration 15, loss = 0.00106744
# /usr/local/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPRegressor(hidden_layer_sizes=10, max_iter=15, random_state=1, verbose=True)

# %%
# calculate score 2 as the autoencoder error
pca_out = NNmodel.predict(data_pca_zs)
error = pca_out - data_pca_zs
oop2=1/p2
score2 = ((error.abs()**p2).sum(axis=1))**oop2

# %%
score2.head(10)
# Out:
# 0    0.032713
# 1    1.062363
# 2    0.023396
# 3    0.025584
# 4    0.030607
# 5    0.018652
# 6    0.021399
# 7    0.021219
# 8    0.028483
# 9    0.028171
# dtype: float64

# %%
scores = pd.DataFrame(score1)
scores.columns=['score1']
scores['score2'] = score2
scores['RECORD'] = save_record
scores.head(10)
# Out:
#       score1    score2  RECORD
# 0   3.111159  0.032713       1
# 1  69.235492  1.062363       2
# 2   0.273789  0.023396       9
# 3   0.469062  0.025584      10
# 4   1.070884  0.030607      11
# 5   0.428559  0.018652      12
# 6   0.284815  0.021399      13
# 7   0.295393  0.021219      14
# 8   0.764182  0.028483      15
# 9   0.733115  0.028171      16

# %%
scores['score1 rank'] = scores['score1'].rank()
scores['score2 rank'] = scores['score2'].rank()
scores.head(20)
# Out:
#        score1    score2  RECORD  score1 rank  score2 rank
# 0    3.111159  0.032713       1    1033738.0     924622.0
# 1   69.235492  1.062363       2    1046696.0    1046048.0
# 2    0.273789  0.023396       9     573498.0     762788.0
# 3    0.469062  0.025584      10     752401.0     809187.0
# 4    1.070884  0.030607      11    1004165.0     900752.0
# 5    0.428559  0.018652      12     715004.0     648262.0
# 6    0.284815  0.021399      13     586879.0     716800.0
# 7    0.295393  0.021219      14     598828.0     712164.0
# 8    0.764182  0.028483      15     980717.0     868128.0
# 9    0.733115  0.028171      16     976676.0     862007.0
# 10   0.733115  0.028171      17     976670.0     862001.0
# 11   0.733115  0.028171      18     976672.0     862003.0
# 12   0.733115  0.028171      19     976674.0     862005.0
# 13   0.733115  0.028171      20     976675.0     862006.0
# 14   0.733115  0.028171      21     976671.0     862002.0
# 15   0.733115  0.028171      22     976673.0     862004.0
# 16   0.732672  0.028166      23     976617.0     861949.0
# 17   0.718084  0.028020      24     974375.0     859272.0
# 18   0.718084  0.028020      25     974376.0     859273.0
# 19   0.754401  0.028385      26     979419.0     866437.0

# %%
# calculate the final score as the average of the two scores
scores['final'] = (.5*scores['score1 rank'] + .5*scores['score2 rank'])
scores_sorted = scores.sort_values(by='final', ascending=False)
scores.head(20)
# Out:
#        score1    score2  RECORD  score1 rank  score2 rank      final
# 0    3.111159  0.032713       1    1033738.0     924622.0   979180.0
# 1   69.235492  1.062363       2    1046696.0    1046048.0  1046372.0
# 2    0.273789  0.023396       9     573498.0     762788.0   668143.0
# 3    0.469062  0.025584      10     752401.0     809187.0   780794.0
# 4    1.070884  0.030607      11    1004165.0     900752.0   952458.5
# 5    0.428559  0.018652      12     715004.0     648262.0   681633.0
# 6    0.284815  0.021399      13     586879.0     716800.0   651839.5
# 7    0.295393  0.021219      14     598828.0     712164.0   655496.0
# 8    0.764182  0.028483      15     980717.0     868128.0   924422.5
# 9    0.733115  0.028171      16     976676.0     862007.0   919341.5
# 10   0.733115  0.028171      17     976670.0     862001.0   919335.5
# 11   0.733115  0.028171      18     976672.0     862003.0   919337.5
# 12   0.733115  0.028171      19     976674.0     862005.0   919339.5
# 13   0.733115  0.028171      20     976675.0     862006.0   919340.5
# 14   0.733115  0.028171      21     976671.0     862002.0   919336.5
# 15   0.733115  0.028171      22     976673.0     862004.0   919338.5
# 16   0.732672  0.028166      23     976617.0     861949.0   919283.0
# 17   0.718084  0.028020      24     974375.0     859272.0   916823.5
# 18   0.718084  0.028020      25     974376.0     859273.0   916824.5
# 19   0.754401  0.028385      26     979419.0     866437.0   922928.0

# %%
scores_sorted.head(10)
# Out:
#              score1      score2   RECORD  score1 rank  score2 rank      final
# 975628   933.839091  220.745250   996722    1046825.0    1046826.0  1046825.5
# 898846   940.878002   71.691718   917942    1046826.0    1046825.0  1046825.5
# 675033   581.345073   38.365287   691986    1046824.0    1046823.0  1046823.5
# 701673   504.329968   35.713909   718883    1046822.0    1046821.0  1046821.5
# 633064   358.966984   68.591168   649717    1046819.0    1046824.0  1046821.5
# 1031078  207.927065   36.696732  1053859    1046810.0    1046822.0  1046816.0
# 759739   257.550518   29.588648   777200    1046817.0    1046808.0  1046812.5
# 936080   560.374108   14.148275   956520    1046823.0    1046798.0  1046810.5
# 642176   424.225756   14.551821   658933    1046820.0    1046799.0  1046809.5
# 7010     199.864449   34.514530     7034    1046803.0    1046815.0  1046809.0

# %%
scores_sorted.tail(10)
# Out:
#           score1    score2  RECORD  score1 rank  score2 rank   final
# 511461  0.058393  0.002424  527096        634.0       4171.0  2402.5
# 400344  0.058735  0.002415  415065        741.0       4048.0  2394.5
# 400478  0.058940  0.002409  415199        790.0       3974.0  2382.0
# 715195  0.060575  0.002320  732459       1627.0       3116.0  2371.5
# 400356  0.059635  0.002371  415077       1135.0       3560.0  2347.5
# 790582  0.061518  0.002204  808270       2278.0       2182.0  2230.0
# 602929  0.060541  0.002276  619299       1601.0       2783.0  2192.0
# 693112  0.060692  0.002262  710272       1689.0       2671.0  2180.0
# 779344  0.058971  0.002339  796921        798.0       3294.0  2046.0
# 800821  0.058892  0.002300  818560        778.0       2979.0  1878.5

# %%
scores.describe()
# Out:
#              score1        score2        RECORD   score1 rank   score2 rank  \
# count  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06
# mean   4.527606e-01  2.350189e-02  5.371221e+05  5.234135e+05  5.234135e+05
# std    2.606724e+00  2.909071e-01  3.080878e+05  3.021928e+05  3.021928e+05
# min    4.744451e-02  1.009656e-03  1.000000e+00  1.000000e+00  1.500000e+00
# 25%    1.450990e-01  7.607892e-03  2.731562e+05  2.617072e+05  2.617072e+05
# 50%    2.404222e-01  1.366771e-02  5.390825e+05  5.234135e+05  5.234095e+05
# 75%    5.027798e-01  2.440871e-02  8.027368e+05  7.851198e+05  7.851195e+05
# max    9.408780e+02  2.207453e+02  1.070994e+06  1.046826e+06  1.046826e+06
#
#               final
# count  1.046826e+06
# mean   5.234135e+05
# std    2.813945e+05
# min    1.878500e+03
# 25%    2.821678e+05
# 50%    5.000905e+05
# 75%    7.735816e+05
# max    1.046826e+06

# %%
scores_sorted.describe()
# Out:
#              score1        score2        RECORD   score1 rank   score2 rank  \
# count  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06  1.046826e+06
# mean   4.527606e-01  2.350189e-02  5.371221e+05  5.234135e+05  5.234135e+05
# std    2.606724e+00  2.909071e-01  3.080878e+05  3.021928e+05  3.021928e+05
# min    4.744451e-02  1.009656e-03  1.000000e+00  1.000000e+00  1.500000e+00
# 25%    1.450990e-01  7.607892e-03  2.731562e+05  2.617072e+05  2.617072e+05
# 50%    2.404222e-01  1.366771e-02  5.390825e+05  5.234135e+05  5.234095e+05
# 75%    5.027798e-01  2.440871e-02  8.027368e+05  7.851198e+05  7.851195e+05
# max    9.408780e+02  2.207453e+02  1.070994e+06  1.046826e+06  1.046826e+06
#
#               final
# count  1.046826e+06
# mean   5.234135e+05
# std    2.813945e+05
# min    1.878500e+03
# 25%    2.821678e+05
# 50%    5.000905e+05
# 75%    7.735816e+05
# max    1.046826e+06

# %%
scores_sorted.set_index('RECORD', drop=True, inplace=True)
scores_sorted.head(10)
# Out:
#              score1      score2  score1 rank  score2 rank      final
# RECORD
# 996722   933.839091  220.745250    1046825.0    1046826.0  1046825.5
# 917942   940.878002   71.691718    1046826.0    1046825.0  1046825.5
# 691986   581.345073   38.365287    1046824.0    1046823.0  1046823.5
# 718883   504.329968   35.713909    1046822.0    1046821.0  1046821.5
# 649717   358.966984   68.591168    1046819.0    1046824.0  1046821.5
# 1053859  207.927065   36.696732    1046810.0    1046822.0  1046816.0
# 777200   257.550518   29.588648    1046817.0    1046808.0  1046812.5
# 956520   560.374108   14.148275    1046823.0    1046798.0  1046810.5
# 658933   424.225756   14.551821    1046820.0    1046799.0  1046809.5
# 7034     199.864449   34.514530    1046803.0    1046815.0  1046809.0

# %%
sc1max = int(score1.max())
plt.hist(score1, bins =100, range=(0,sc1max+1))
plt.yscale('log')
plt.ylim(ymin=.1)
# Out:
# (0.1, 2089149.628010629)

# %%
sc2max = int(score2.max())
sc2max
# Out:
# 220

# %%
sc2max = int(score2.max())
print(sc2max)
plt.hist(score2, bins =100, range=(0,sc2max+1))
plt.yscale('log')
plt.ylim(ymin=.1)
# Out:
# 220
# (0.1, 2092817.813427145)

# %%
sns.displot(scores['final'])

# %%
top_records = scores_sorted.head(ntop).index
print(top_records)
# Out:
# Int64Index([ 996722,  917942,  691986,  718883,  649717, 1053859,  777200,
#              956520,  658933,    7034,
#             ...
#              284190,  284200,  284201,  284211,  284198,  284202,  284210,
#              284180,  284189,  284205],
#            dtype='int64', name='RECORD', length=1000)

# %%
data_zs['RECORD'] = save_record
data_zs.set_index('RECORD', inplace=True, drop=True)
data_zs.head()
# Out:
#                 r1         r2         r3         r4        r5        r6  \
# RECORD
# 1        -0.324189   3.365634   0.962071  -0.034088  2.023461  0.745320
# 2       107.903135  34.685411  12.654552  60.713604  6.996480  2.658471
# 9         0.322241   0.194554  -0.459794   0.738056  0.253399 -0.042992
# 10        0.644229   0.513596  -0.446651   1.133208  0.393046 -0.037064
# 11        1.542460   1.403606  -0.409988   1.200500  0.416827 -0.036055
#
#                 r7         r8        r9     r1inv  ...   r9_boro  r1inv_boro  \
# RECORD                                             ...
# 1        -0.041301   1.874086  0.937911 -0.015279  ...  0.887478   -0.015678
# 2       127.179921  17.407961  8.963675 -0.019486  ...  8.549314   -0.017466
# 9         0.718576   0.301305 -0.038062 -0.019041  ... -0.044240   -0.017277
# 10        1.097074   0.459542 -0.029041 -0.019179  ... -0.035628   -0.017335
# 11        2.152944   0.900967 -0.003875 -0.019322  ... -0.011603   -0.017396
#
#         r2inv_boro  r3inv_boro  r4inv_boro  r5inv_boro  r6inv_boro  \
# RECORD
# 1        -0.022354   -0.020917   -0.018898   -0.051015   -0.033996
# 2        -0.022386   -0.020925   -0.019644   -0.051036   -0.034000
# 9        -0.022189   -0.020469   -0.019548   -0.050851   -0.033701
# 10       -0.022251   -0.020609   -0.019578   -0.050911   -0.033794
# 11       -0.022316   -0.020756   -0.019582   -0.050917   -0.033804
#
#         r7inv_boro  r8inv_boro  r9inv_boro
# RECORD
# 1        -0.014258   -0.040323   -0.046264
# 2        -0.015962   -0.040385   -0.046283
# 9        -0.015782   -0.040014   -0.045241
# 10       -0.015838   -0.040131   -0.045563
# 11       -0.015896   -0.040252   -0.045897
#
# [5 rows x 90 columns]

# %%
data_zs_top_n = data_zs.loc[top_records]
data_zs_top_n.transpose()
# Out:
# RECORD         996722      917942      691986      718883      649717   \
# r1           -0.401017    0.748372   -0.401020   -0.401019   -0.401020
# r2           -0.522013   67.425821   -0.522087   -0.522087   -0.522084
# r3           -0.489278   46.162233   -0.489316   -0.489316   -0.489314
# r4           -0.149547   41.781054   -0.149533   -0.062929   -0.149544
# r5           -0.060280  884.036490   -0.060276   -0.035784   -0.060276
# ...                ...         ...         ...         ...         ...
# r5inv_boro  174.972244   -0.051044   37.928851   -0.043399   37.928851
# r6inv_boro  103.273998   -0.034001   19.530223   -0.024008   19.530223
# r7inv_boro  944.698744   -0.015956   51.928600   74.017774  243.139595
# r8inv_boro  159.761215   -0.040393   79.717483  142.004459   79.717483
# r9inv_boro  157.237747   -0.046285  105.463825  476.769696  105.463825
#
# RECORD        1053859     777200     956520     658933      7034     ...  \
# r1          -0.401020   -0.401019  -0.113628   0.181820   -0.401018  ...
# r2          -0.522006   -0.522086  -0.522051  -0.522034   -0.522086  ...
# r3          -0.489285   -0.489315  -0.489290  -0.489279   -0.489316  ...
# r4          -0.149544   -0.149536  -0.051554   0.004449   -0.149545  ...
# r5          -0.060181   -0.060276  -0.060277  -0.060276   -0.060280  ...
# ...               ...         ...        ...        ...         ...  ...
# r5inv_boro   1.363554   37.928851  31.202957  36.789271  109.304763  ...
# r6inv_boro   1.117686   19.530223  13.801822  10.284823   44.181253  ...
# r7inv_boro  38.765429   69.414815  -0.015106  -0.013240   45.805818  ...
# r8inv_boro   1.251178   79.717483  21.267255  44.723493  119.850219  ...
# r9inv_boro   1.707132  105.463825  15.682684  32.153005   85.765770  ...
#
# RECORD        284190     284200     284201     284211     284198     284202   \
# r1          -0.400562  -0.400562  -0.400562  -0.400562  -0.400562  -0.400562
# r2          -0.521634  -0.521634  -0.521634  -0.521634  -0.521634  -0.521634
# r3          -0.489238  -0.489238  -0.489238  -0.489238  -0.489238  -0.489238
# r4          -0.149522  -0.149522  -0.149522  -0.149522  -0.149522  -0.149522
# r5          -0.060272  -0.060272  -0.060272  -0.060272  -0.060272  -0.060272
# ...               ...        ...        ...        ...        ...        ...
# r5inv_boro  14.631679  14.631679  14.631679  14.631679  14.631679  14.631679
# r6inv_boro   9.286954   9.286954   9.286954   9.286954   9.286954   9.286954
# r7inv_boro   0.479192   0.479192   0.479192   0.479192   0.479192   0.479192
# r8inv_boro   0.772396   0.772396   0.772396   0.772396   0.772396   0.772396
# r9inv_boro   1.765224   1.765224   1.765224   1.765224   1.765224   1.765224
#
# RECORD        284210     284180     284189     284205
# r1          -0.400562  -0.400562  -0.400562  -0.400562
# r2          -0.521634  -0.521634  -0.521634  -0.521634
# r3          -0.489238  -0.489238  -0.489238  -0.489238
# r4          -0.149522  -0.149522  -0.149522  -0.149522
# r5          -0.060272  -0.060272  -0.060272  -0.060272
# ...               ...        ...        ...        ...
# r5inv_boro  14.631679  14.631679  14.631679  14.631679
# r6inv_boro   9.286954   9.286954   9.286954   9.286954
# r7inv_boro   0.479192   0.479192   0.479192   0.479192
# r8inv_boro   0.772396   0.772396   0.772396   0.772396
# r9inv_boro   1.765224   1.765224   1.765224   1.765224
#
# [90 rows x 1000 columns]

# %%
scores.set_index('RECORD',inplace=True)
scores.drop(columns=['score1','score2'],inplace=True)
scores.head(30)
# Out:
#         score1 rank  score2 rank       final
# RECORD
# 1         1033738.0     924622.0   979180.00
# 2         1046696.0    1046048.0  1046372.00
# 9          573498.0     762788.0   668143.00
# 10         752401.0     809187.0   780794.00
# 11        1004165.0     900752.0   952458.50
# 12         715004.0     648262.0   681633.00
# 13         586879.0     716800.0   651839.50
# 14         598828.0     712164.0   655496.00
# 15         980717.0     868128.0   924422.50
# 16         976676.0     862007.0   919341.50
# 17         976670.0     862001.0   919335.50
# 18         976672.0     862003.0   919337.50
# 19         976674.0     862005.0   919339.50
# 20         976675.0     862006.0   919340.50
# 21         976671.0     862002.0   919336.50
# 22         976673.0     862004.0   919338.50
# 23         976617.0     861949.0   919283.00
# 24         974375.0     859272.0   916823.50
# 25         974376.0     859273.0   916824.50
# 26         979419.0     866437.0   922928.00
# 27         979421.0     866438.0   922929.50
# 28         979420.0     866436.0   922928.00
# 29         979422.0     866435.0   922928.50
# 30         979079.0     865921.0   922500.00
# 31         669659.0     789301.0   729480.00
# 32         669650.0     789299.0   729474.50
# 33         669652.0     789300.0   729476.00
# 34         669657.0     789306.0   729481.50
# 35         669654.5     789302.0   729478.25
# 36         669658.0     789304.0   729481.00

# %%
# NY_data_with_scores = NY_data_orig.join(scores, on='RECORD', rsuffix='_scores')
NY_data_with_scores = NY_data_orig.join(scores, on='RECORD')
NY_data_with_scores.set_index('RECORD',inplace=True)
NY_data_with_scores.head(10)
# Out:
#               BBLE  BORO  BLOCK   LOT EASEMENT                  OWNER BLDGCL  \
# RECORD
# 1       1000010101     1      1   101      NaN  U S GOVT LAND & BLDGS     P7
# 2       1000010201     1      1   201      NaN  U S GOVT LAND & BLDGS     Z9
# 3       1000020001     1      2     1      NaN  DEPT OF GENERAL SERVI     Y7
# 4       1000020023     1      2    23      NaN  DEPARTMENT OF BUSINES     T2
# 5       1000030001     1      3     1      NaN   PARKS AND RECREATION     Q1
# 6       1000030002     1      3     2      NaN   PARKS AND RECREATION     Q1
# 7       1000030003     1      3     3      NaN   PARKS AND RECREATION     Q1
# 8       1000030010     1      3    10      NaN     DEPT RE-CITY OF NY     Z9
# 9       1000041001     1      4  1001      NaN      TRZ HOLDINGS, LLC     R5
# 10      1000041002     1      4  1002      NaN      TRZ HOLDINGS, LLC     R5
#
#        TAXCLASS  LTFRONT  LTDEPTH  ...       AVTOT2      EXLAND2       EXTOT2  \
# RECORD                             ...
# 1             4      500     1046  ...    8613000.0    3775500.0    8613000.0
# 2             4       27        0  ...   80690400.0   11111400.0   80690400.0
# 3             4      709      564  ...   40179510.0   32321790.0   40179510.0
# 4             4      793      551  ...   15750000.0   13644000.0   15750000.0
# 5             4      323     1260  ...  107758350.0  106348680.0  107758350.0
# 6             4      496       76  ...    4268700.0    4268700.0    4268700.0
# 7             4      180      370  ...    3546900.0    3546900.0    3546900.0
# 8             4      362      177  ...   11304000.0    9882000.0   11304000.0
# 9             4        0        0  ...    2049290.0          NaN          NaN
# 10            4        0        0  ...    2961617.0          NaN          NaN
#
#         EXCD2  PERIOD     YEAR  VALTYPE  score1 rank score2 rank      final
# RECORD
# 1         NaN   FINAL  2010/11    AC-TR    1033738.0    924622.0   979180.0
# 2         NaN   FINAL  2010/11    AC-TR    1046696.0   1046048.0  1046372.0
# 3         NaN   FINAL  2010/11    AC-TR          NaN         NaN        NaN
# 4         NaN   FINAL  2010/11    AC-TR          NaN         NaN        NaN
# 5         NaN   FINAL  2010/11    AC-TR          NaN         NaN        NaN
# 6         NaN   FINAL  2010/11    AC-TR          NaN         NaN        NaN
# 7         NaN   FINAL  2010/11    AC-TR          NaN         NaN        NaN
# 8         NaN   FINAL  2010/11    AC-TR          NaN         NaN        NaN
# 9         NaN   FINAL  2010/11    AC-TR     573498.0    762788.0   668143.0
# 10        NaN   FINAL  2010/11    AC-TR     752401.0    809187.0   780794.0
#
# [10 rows x 34 columns]

# %%
NY_data_top_n = NY_data_with_scores.sort_values(['final'], ascending = False).head(ntop)
NY_data_top_n
# Out:
#               BBLE  BORO  BLOCK   LOT EASEMENT                  OWNER BLDGCL  \
# RECORD
# 996722  5029220125     5   2922   125      NaN  IMPERIAL COURT HOMEOW     V0
# 917942  4142600001     4  14260     1      NaN   LOGAN PROPERTY, INC.     T1
# 691986  4039160200     4   3916   200      NaN  TITAN SOUNDVIEW POINT     Z7
# 718883  4051251107     4   5125  1107      NaN        GARDEN VIEW LTD     R4
# 649717  4025270002     4   2527     2      NaN              57-43 LLC     V1
# ...            ...   ...    ...   ...      ...                    ...    ...
# 284202  3009641270     3    964  1270      NaN                    NaN     R5
# 284210  3009641278     3    964  1278      NaN                    NaN     R5
# 284180  3009641248     3    964  1248      NaN                    NaN     R5
# 284189  3009641257     3    964  1257      NaN                    NaN     R5
# 284205  3009641273     3    964  1273      NaN                    NaN     R5
#
#        TAXCLASS  LTFRONT  LTDEPTH  ...        AVTOT2       EXLAND2  \
# RECORD                             ...
# 996722       1B      300      400  ...           NaN           NaN
# 917942        4     4910        0  ...  4.501180e+09  1.644454e+09
# 691986        4        0        0  ...  3.000000e+00           NaN
# 718883        2        0        0  ...           NaN           NaN
# 649717        4       51      940  ...           NaN           NaN
# ...         ...      ...      ...  ...           ...           ...
# 284202        4        0        0  ...  1.123000e+03           NaN
# 284210        4        0        0  ...  1.123000e+03           NaN
# 284180        4        0        0  ...  1.123000e+03           NaN
# 284189        4        0        0  ...  1.123000e+03           NaN
# 284205        4        0        0  ...  1.123000e+03           NaN
#
#               EXTOT2  EXCD2  PERIOD     YEAR  VALTYPE  score1 rank  \
# RECORD
# 996722           NaN    NaN   FINAL  2010/11    AC-TR    1046825.0
# 917942  4.501180e+09    NaN   FINAL  2010/11    AC-TR    1046826.0
# 691986           NaN    NaN   FINAL  2010/11    AC-TR    1046824.0
# 718883           NaN    NaN   FINAL  2010/11    AC-TR    1046822.0
# 649717           NaN    NaN   FINAL  2010/11    AC-TR    1046819.0
# ...              ...    ...     ...      ...      ...          ...
# 284202           NaN    NaN   FINAL  2010/11    AC-TR    1044790.0
# 284210           NaN    NaN   FINAL  2010/11    AC-TR    1044790.0
# 284180           NaN    NaN   FINAL  2010/11    AC-TR    1044790.0
# 284189           NaN    NaN   FINAL  2010/11    AC-TR    1044790.0
# 284205           NaN    NaN   FINAL  2010/11    AC-TR    1044790.0
#
#        score2 rank      final
# RECORD
# 996722   1046826.0  1046825.5
# 917942   1046825.0  1046825.5
# 691986   1046823.0  1046823.5
# 718883   1046821.0  1046821.5
# 649717   1046824.0  1046821.5
# ...            ...        ...
# 284202   1046156.0  1045473.0
# 284210   1046156.0  1045473.0
# 284180   1046156.0  1045473.0
# 284189   1046156.0  1045473.0
# 284205   1046156.0  1045473.0
#
# [1000 rows x 34 columns]

# %%
NY_data_top_n['OWNER'].head(40)
# Out:
# RECORD
# 996722     IMPERIAL COURT HOMEOW
# 917942      LOGAN PROPERTY, INC.
# 691986     TITAN SOUNDVIEW POINT
# 718883           GARDEN VIEW LTD
# 649717                 57-43 LLC
# 1053859                      NaN
# 777200     NY STATE PUBLIC WORKS
# 956520         TROMPETA RIZALINA
# 658933           WAN CHIU CHEUNG
# 7034              HSIA, JONATHAN
# 995567                       NaN
# 7040            BILINKAS, EDWARD
# 7039              LAMBERT, PETER
# 7038               OWEN, MICHAEL
# 7037                 HANLON, AMY
# 7036             LECH, JOHN PAUL
# 7035                NOVARO, HUGO
# 7042           SWENDSRUD, MONICA
# 7041                         NaN
# 7033                         NaN
# 7043                CHOI, JOSEPH
# 459429                       NaN
# 934793     BREEZY POINT COOPERAT
# 243059      SILVER BEACH GARDENS
# 114694                       NaN
# 1059883                      NaN
# 1048475    PARK VILLAGE RESIDENT
# 845810           WILLIAM A. LOTT
# 241946       RUFFALO ENTERPRISES
# 1000954    MATIONAL COLLECTORS &
# 665158         ST JOHNS CEMETERY
# 524297             MARTIN OLINER
# 1045012           LINDA VITALONE
# 288274                       NaN
# 1042323    NYC DEP'T OF HIGHWAYS
# 252834                       NaN
# 448369            GIORDANO PETER
# 111420     BOXWOOD FLTD PARNTERS
# 811018             EWALD DEMENYS
# 982930     FOREST VIEW HOMEOWNER
# Name: OWNER, dtype: object

# %%
NY_data_top_n.shape
# Out:
# (1000, 34)

# %%
data_zs_top_n.shape
# Out:
# (1000, 90)

# %%
NY_top_with_zs = pd.concat([NY_data_top_n,data_zs_top_n],axis=1)
NY_top_with_zs.shape
# Out:
# (1000, 124)

# %%
NY_top_with_zs.to_excel('NY_top_with_zs.xlsx', index=True)
NY_data_top_n.to_excel('NY_top.xlsx', index=True)
data_zs_top_n.to_csv('data_zs_top.csv', index=True)

# %%
data_zs_top_n.shape
# Out:
# (1000, 90)

# %%
# The heatmaps are good for seeing which variables are driving the high scores
data_base_vars = data_zs_top_n.iloc[:,0:17].abs()
data_heatmap = data_base_vars.head(20)
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_zs_top_n_abs = data_zs_top_n.abs()
data_heatmap = data_zs_top_n.abs().head(20)
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
NY_data_top_n.head(30)
# Out:
#                 BBLE  BORO  BLOCK   LOT EASEMENT                  OWNER  \
# RECORD
# 996722    5029220125     5   2922   125      NaN  IMPERIAL COURT HOMEOW
# 917942    4142600001     4  14260     1      NaN   LOGAN PROPERTY, INC.
# 691986    4039160200     4   3916   200      NaN  TITAN SOUNDVIEW POINT
# 718883    4051251107     4   5125  1107      NaN        GARDEN VIEW LTD
# 649717    4025270002     4   2527     2      NaN              57-43 LLC
# 1053859   5064310100     5   6431   100      NaN                    NaN
# 777200   4080990145E     4   8099   145        E  NY STATE PUBLIC WORKS
# 956520    5006590012     5    659    12      NaN      TROMPETA RIZALINA
# 658933    4029060054     4   2906    54      NaN        WAN CHIU CHEUNG
# 7034      1000531146     1     53  1146      NaN         HSIA, JONATHAN
# 995567    5028730105     5   2873   105      NaN                    NaN
# 7040      1000531152     1     53  1152      NaN       BILINKAS, EDWARD
# 7039      1000531151     1     53  1151      NaN         LAMBERT, PETER
# 7038      1000531150     1     53  1150      NaN          OWEN, MICHAEL
# 7037      1000531149     1     53  1149      NaN            HANLON, AMY
# 7036      1000531148     1     53  1148      NaN        LECH, JOHN PAUL
# 7035      1000531147     1     53  1147      NaN           NOVARO, HUGO
# 7042      1000531154     1     53  1154      NaN      SWENDSRUD, MONICA
# 7041      1000531153     1     53  1153      NaN                    NaN
# 7033      1000531145     1     53  1145      NaN                    NaN
# 7043      1000531155     1     53  1155      NaN           CHOI, JOSEPH
# 459429    3059930075     3   5993    75      NaN                    NaN
# 934793    4163500400     4  16350   400      NaN  BREEZY POINT COOPERAT
# 243059    2055060001     2   5506     1      NaN   SILVER BEACH GARDENS
# 114694    1015341320     1   1534  1320      NaN                    NaN
# 1059883  5069770012E     5   6977    12        E                    NaN
# 1048475   5060250045     5   6025    45      NaN  PARK VILLAGE RESIDENT
# 845810    4108320045     4  10832    45      NaN        WILLIAM A. LOTT
# 241946    2054670100     2   5467   100      NaN    RUFFALO ENTERPRISES
# 1000954   5031240104     5   3124   104      NaN  MATIONAL COLLECTORS &
#
#         BLDGCL TAXCLASS  LTFRONT  LTDEPTH  ...        AVTOT2       EXLAND2  \
# RECORD                                     ...
# 996722      V0       1B      300      400  ...           NaN           NaN
# 917942      T1        4     4910        0  ...  4.501180e+09  1.644454e+09
# 691986      Z7        4        0        0  ...  3.000000e+00           NaN
# 718883      R4        2        0        0  ...           NaN           NaN
# 649717      V1        4       51      940  ...           NaN           NaN
# 1053859     Z7        4     1000     1000  ...  1.390000e+02           NaN
# 777200      Z7        4      110        0  ...           NaN           NaN
# 956520      A1        1       25       91  ...           NaN           NaN
# 658933      C0        1       25      100  ...           NaN           NaN
# 7034        R4        2        0        0  ...           NaN           NaN
# 995567      Z7        4      100      200  ...           NaN           NaN
# 7040        R4        2        0        0  ...           NaN           NaN
# 7039        R4        2        0        0  ...           NaN           NaN
# 7038        R4        2        0        0  ...           NaN           NaN
# 7037        R4        2        0        0  ...           NaN           NaN
# 7036        R4        2        0        0  ...           NaN           NaN
# 7035        R4        2        0        0  ...           NaN           NaN
# 7042        R4        2        0        0  ...           NaN           NaN
# 7041        R4        2        0        0  ...           NaN           NaN
# 7033        R4        2        0        0  ...           NaN           NaN
# 7043        R4        2        0        0  ...           NaN           NaN
# 459429      V0       1B        8      100  ...           NaN           NaN
# 934793      A8       1D     2798      997  ...           NaN           NaN
# 243059      A8       1D      999      556  ...           NaN           NaN
# 114694      R4        2        0        0  ...           NaN           NaN
# 1059883     Z7        4        5        5  ...           NaN           NaN
# 1048475     Q1        4      324     3000  ...           NaN           NaN
# 845810      V0       1B        1        1  ...           NaN           NaN
# 241946      V0       1B      503      999  ...           NaN           NaN
# 1000954     Z7        4      176      500  ...           NaN           NaN
#
#                EXTOT2   EXCD2  PERIOD     YEAR  VALTYPE  score1 rank  \
# RECORD
# 996722            NaN     NaN   FINAL  2010/11    AC-TR    1046825.0
# 917942   4.501180e+09     NaN   FINAL  2010/11    AC-TR    1046826.0
# 691986            NaN     NaN   FINAL  2010/11    AC-TR    1046824.0
# 718883            NaN     NaN   FINAL  2010/11    AC-TR    1046822.0
# 649717            NaN     NaN   FINAL  2010/11    AC-TR    1046819.0
# 1053859           NaN     NaN   FINAL  2010/11    AC-TR    1046810.0
# 777200            NaN     NaN   FINAL  2010/11    AC-TR    1046817.0
# 956520            NaN     NaN   FINAL  2010/11    AC-TR    1046823.0
# 658933            NaN     NaN   FINAL  2010/11    AC-TR    1046820.0
# 7034              NaN     NaN   FINAL  2010/11    AC-TR    1046803.0
# 995567            NaN     NaN   FINAL  2010/11    AC-TR    1046809.0
# 7040              NaN     NaN   FINAL  2010/11    AC-TR    1046803.0
# 7039              NaN     NaN   FINAL  2010/11    AC-TR    1046803.0
# 7038              NaN     NaN   FINAL  2010/11    AC-TR    1046803.0
# 7037              NaN     NaN   FINAL  2010/11    AC-TR    1046803.0
# 7036              NaN     NaN   FINAL  2010/11    AC-TR    1046803.0
# 7035              NaN     NaN   FINAL  2010/11    AC-TR    1046803.0
# 7042              NaN     NaN   FINAL  2010/11    AC-TR    1046803.0
# 7041              NaN     NaN   FINAL  2010/11    AC-TR    1046803.0
# 7033              NaN     NaN   FINAL  2010/11    AC-TR    1046803.0
# 7043              NaN     NaN   FINAL  2010/11    AC-TR    1046803.0
# 459429            NaN     NaN   FINAL  2010/11    AC-TR    1046821.0
# 934793            NaN  1015.0   FINAL  2010/11    AC-TR    1046811.0
# 243059            NaN  1015.0   FINAL  2010/11    AC-TR    1046788.0
# 114694            NaN     NaN   FINAL  2010/11    AC-TR    1046759.0
# 1059883           NaN     NaN   FINAL  2010/11    AC-TR    1046818.0
# 1048475           NaN     NaN   FINAL  2010/11    AC-TR    1046754.0
# 845810            NaN     NaN   FINAL  2010/11    AC-TR    1046764.0
# 241946            NaN     NaN   FINAL  2010/11    AC-TR    1046743.0
# 1000954           NaN     NaN   FINAL  2010/11    AC-TR    1046739.0
#
#         score2 rank      final
# RECORD
# 996722    1046826.0  1046825.5
# 917942    1046825.0  1046825.5
# 691986    1046823.0  1046823.5
# 718883    1046821.0  1046821.5
# 649717    1046824.0  1046821.5
# 1053859   1046822.0  1046816.0
# 777200    1046808.0  1046812.5
# 956520    1046798.0  1046810.5
# 658933    1046799.0  1046809.5
# 7034      1046815.0  1046809.0
# 995567    1046809.0  1046809.0
# 7040      1046815.0  1046809.0
# 7039      1046815.0  1046809.0
# 7038      1046815.0  1046809.0
# 7037      1046815.0  1046809.0
# 7036      1046815.0  1046809.0
# 7035      1046815.0  1046809.0
# 7042      1046815.0  1046809.0
# 7041      1046815.0  1046809.0
# 7033      1046815.0  1046809.0
# 7043      1046815.0  1046809.0
# 459429    1046794.0  1046807.5
# 934793    1046796.0  1046803.5
# 243059    1046797.0  1046792.5
# 114694    1046807.0  1046783.0
# 1059883   1046744.0  1046781.0
# 1048475   1046801.0  1046777.5
# 845810    1046790.0  1046777.0
# 241946    1046806.0  1046774.5
# 1000954   1046802.0  1046770.5
#
# [30 rows x 34 columns]

# %%
data_zs_top_n_abs
# Out:
#               r1         r2         r3         r4          r5          r6  \
# RECORD
# 996722  0.401017   0.522013   0.489278   0.149547    0.060280    0.056308
# 917942  0.748372  67.425821  46.162233  41.781054  884.036490  625.448873
# 691986  0.401020   0.522087   0.489316   0.149533    0.060276    0.056306
# 718883  0.401019   0.522087   0.489316   0.062929    0.035784    0.052594
# 649717  0.401020   0.522084   0.489314   0.149544    0.060276    0.056306
# ...          ...        ...        ...        ...         ...         ...
# 284202  0.400562   0.521634   0.489238   0.149522    0.060272    0.056307
# 284210  0.400562   0.521634   0.489238   0.149522    0.060272    0.056307
# 284180  0.400562   0.521634   0.489238   0.149522    0.060272    0.056307
# 284189  0.400562   0.521634   0.489238   0.149522    0.060272    0.056307
# 284205  0.400562   0.521634   0.489238   0.149522    0.060272    0.056307
#
#                r7          r8          r9       r1inv  ...     r9_boro  \
# RECORD                                                 ...
# 996722   0.131617    0.054132    0.058326   82.652966  ...    0.063585
# 917942  37.343529  934.683271  888.115885    0.019207  ...  878.644110
# 691986   0.131612    0.054130    0.058325  440.955064  ...    0.063584
# 718883   0.131614    0.054131    0.058326  209.479461  ...    0.063585
# 649717   0.131616    0.054130    0.058325  375.294667  ...    0.063584
# ...           ...         ...         ...         ...  ...         ...
# 284202   0.131078    0.053907    0.058273    0.686071  ...    0.063517
# 284210   0.131078    0.053907    0.058273    0.686071  ...    0.063517
# 284180   0.131078    0.053907    0.058273    0.686071  ...    0.063517
# 284189   0.131078    0.053907    0.058273    0.686071  ...    0.063517
# 284205   0.131078    0.053907    0.058273    0.686071  ...    0.063517
#
#         r1inv_boro  r2inv_boro  r3inv_boro  r4inv_boro  r5inv_boro  \
# RECORD
# 996722   42.937024    1.482004    0.994522  946.488587  174.972244
# 917942    0.017069    0.022383    0.020923    0.019640    0.051044
# 691986  623.760734  734.299300  515.504434   17.512301   37.928851
# 718883  296.328155  435.907872  776.557831    0.016821    0.043399
# 649717  530.881168  133.490644   93.710958   82.048427   37.928851
# ...            ...         ...         ...         ...         ...
# 284202    0.973640    1.135203    1.253050    6.153289   14.631679
# 284210    0.973640    1.135203    1.253050    6.153289   14.631679
# 284180    0.973640    1.135203    1.253050    6.153289   14.631679
# 284189    0.973640    1.135203    1.253050    6.153289   14.631679
# 284205    0.973640    1.135203    1.253050    6.153289   14.631679
#
#         r6inv_boro  r7inv_boro  r8inv_boro  r9inv_boro
# RECORD
# 996722  103.273998  944.698744  159.761215  157.237747
# 917942    0.034001    0.015956    0.040393    0.046285
# 691986   19.530223   51.928600   79.717483  105.463825
# 718883    0.024008   74.017774  142.004459  476.769696
# 649717   19.530223  243.139595   79.717483  105.463825
# ...            ...         ...         ...         ...
# 284202    9.286954    0.479192    0.772396    1.765224
# 284210    9.286954    0.479192    0.772396    1.765224
# 284180    9.286954    0.479192    0.772396    1.765224
# 284189    9.286954    0.479192    0.772396    1.765224
# 284205    9.286954    0.479192    0.772396    1.765224
#
# [1000 rows x 90 columns]

# %%
top_records_df = pd.DataFrame(top_records)

# %%
# Use this cell if you want to write out the top n record numbers
top_records_df.to_csv('top_n_record_numbers.csv', index=False)

# %%
# # Use this cell if you want to compare to a previous top n record numbers.
# # You can run a baseline model, see which records score the highest, then change some of the algorithm parameters
# # to see what % of these top scoring records change. The top records are insensitive to changes in the 
# # powers for the Minkowski distance measures for the two scores

# top_records_previous = pd.read_csv('top_n_record_numbers.csv')
# print(top_records_df.head())
# print(top_records_previous.head())
# num_common = len(pd.merge(top_records_df,top_records_previous, on='RECORD'))
# percent_common = 100*num_common/ntop
# percent_common

# %%
print('Duration: ', datetime.now() - start_time)
# Out:
# Duration:  0:04:18.400934

# %% [markdown]
# ### PROPERTY ANALYSIS

# %%
# looking at random 12

# %%
NY_data_with_scores_sorted = NY_data_with_scores.sort_values(['final'], ascending = False)

# %%
NY_data_with_scores_sorted.final.std()
# Out:
# 281394.454219526

# %%
cols_to_check = ['LTFRONT', 'LTDEPTH', 'BLDFRONT', 'BLDDEPTH', 'STORIES']

# %%
NY_data_with_scores.loc[[243059, 658933, 934793, 956520]][cols_to_check]
# Out:
#         LTFRONT  LTDEPTH  BLDFRONT  BLDDEPTH  STORIES
# RECORD
# 243059      999      556        16        30      1.0
# 658933       25      100      2500      5600      3.0
# 934793     2798      997        30        40      1.0
# 956520       25       91      1812      5020      3.0

# %%
NY_data_with_scores.loc[934793]
# Out:
# BBLE                         4163500400
# BORO                                  4
# BLOCK                             16350
# LOT                                 400
# EASEMENT                            NaN
# OWNER             BREEZY POINT COOPERAT
# BLDGCL                               A8
# TAXCLASS                             1D
# LTFRONT                            2798
# LTDEPTH                             997
# EXT                                 NaN
# STORIES                             1.0
# FULLVAL                     273000000.0
# AVLAND                       10920000.0
# AVTOT                        16380000.0
# EXLAND                         768206.0
# EXTOT                         1133406.0
# EXCD1                            1010.0
# STADDR         217-02 BREEZY POINT BLVD
# ZIP                             11697.0
# EXMPTCL                             NaN
# BLDFRONT                             30
# BLDDEPTH                             40
# AVLAND2                             NaN
# AVTOT2                              NaN
# EXLAND2                             NaN
# EXTOT2                              NaN
# EXCD2                            1015.0
# PERIOD                            FINAL
# YEAR                            2010/11
# VALTYPE                           AC-TR
# score1 rank                   1046811.0
# score2 rank                   1046796.0
# final                         1046803.5
# Name: 934793, dtype: object

# %%
unusual_samples = data_zs_top_n_abs.head(80)
mylist = []
missing_values = []
cols_to_check = ['LTFRONT', 'LTDEPTH', 'BLDFRONT', 'BLDDEPTH', 'STORIES']

for i in unusual_samples.index:
    unusual_vars = unusual_samples.loc[i] > 50
    print(f'For record {i} we have {unusual_vars.sum()} strange values')
#     print(unusual_samples.columns[unusual_vars].to_list())
    orig_rec = NY_data_top_n.loc[i]
    if unusual_vars.sum() > 0:
        mylist.append(i)
        if (orig_rec[cols_to_check] == 0).any():
            missing_values.append(i)
# Out:
# For record 996722 we have 29 strange values
# For record 917942 we have 30 strange values
# For record 691986 we have 31 strange values
# For record 718883 we have 29 strange values
# For record 649717 we have 31 strange values
# For record 1053859 we have 9 strange values
# For record 777200 we have 26 strange values
# For record 956520 we have 8 strange values
# For record 658933 we have 6 strange values
# For record 7034 we have 29 strange values
# For record 995567 we have 19 strange values
# For record 7040 we have 29 strange values
# For record 7039 we have 29 strange values
# For record 7038 we have 29 strange values
# For record 7037 we have 29 strange values
# For record 7036 we have 29 strange values
# For record 7035 we have 29 strange values
# For record 7042 we have 29 strange values
# For record 7041 we have 29 strange values
# For record 7033 we have 29 strange values
# For record 7043 we have 29 strange values
# For record 459429 we have 15 strange values
# For record 934793 we have 8 strange values
# For record 243059 we have 8 strange values
# For record 114694 we have 24 strange values
# For record 1059883 we have 15 strange values
# For record 1048475 we have 8 strange values
# For record 845810 we have 15 strange values
# For record 241946 we have 6 strange values
# For record 1000954 we have 8 strange values
# For record 665158 we have 30 strange values
# For record 524297 we have 8 strange values
# For record 1045012 we have 8 strange values
# For record 288274 we have 7 strange values
# For record 1042323 we have 15 strange values
# For record 252834 we have 15 strange values
# For record 448369 we have 6 strange values
# For record 111420 we have 28 strange values
# For record 811018 we have 7 strange values
# For record 982930 we have 4 strange values
# For record 410505 we have 8 strange values
# For record 980276 we have 3 strange values
# For record 253179 we have 13 strange values
# For record 253181 we have 13 strange values
# For record 535114 we have 6 strange values
# For record 435070 we have 6 strange values
# For record 847492 we have 7 strange values
# For record 701719 we have 2 strange values
# For record 333412 we have 4 strange values
# For record 12076 we have 27 strange values
# For record 610682 we have 15 strange values
# For record 330292 we have 25 strange values
# For record 794108 we have 7 strange values
# For record 638993 we have 26 strange values
# For record 973912 we have 30 strange values
# For record 382398 we have 4 strange values
# For record 147578 we have 5 strange values
# For record 1013941 we have 6 strange values
# For record 796933 we have 2 strange values
# For record 912500 we have 4 strange values
# For record 665157 we have 29 strange values
# For record 210362 we have 4 strange values
# For record 151044 we have 21 strange values
# For record 139726 we have 15 strange values
# For record 684704 we have 10 strange values
# For record 723532 we have 4 strange values
# For record 1042324 we have 11 strange values
# For record 229616 we have 4 strange values
# For record 649675 we have 14 strange values
# For record 598251 we have 6 strange values
# For record 1065208 we have 11 strange values
# For record 539374 we have 8 strange values
# For record 33564 we have 23 strange values
# For record 383006 we have 8 strange values
# For record 860520 we have 8 strange values
# For record 934780 we have 6 strange values
# For record 116647 we have 14 strange values
# For record 817296 we have 25 strange values
# For record 817349 we have 12 strange values
# For record 750325 we have 7 strange values

# %%
len(mylist)
# Out:
# 80

# %%
len(missing_values)
# Out:
# 63

# %%
interesting_indexes = set(mylist) - set(missing_values)
interesting_indexes
# Out:
# {12076,
#  33564,
#  111420,
#  116647,
#  243059,
#  330292,
#  333412,
#  638993,
#  658933,
#  665157,
#  665158,
#  817296,
#  934780,
#  934793,
#  956520,
#  973912,
#  980276}

# %%
record_inv = 7033
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
# Out:
# r1                  0.401018
# r2                  0.522086
# r3                  0.489316
# r4                  0.149545
# r5                  0.060280
# r6                  0.056308
# r7                  0.131614
# r8                  0.054131
# r9                  0.058326
# r1inv             139.646478
# r2inv             173.856631
# r3inv             233.003211
# r4inv              59.414433
# r5inv             210.862453
# r6inv             160.486512
# r7inv              12.351019
# r8inv             107.660811
# r9inv             210.536053
# r1_zip5             0.462244
# r2_zip5             0.469001
# r3_zip5             0.366531
# r4_zip5             0.195022
# r5_zip5             0.122415
# r6_zip5             0.099852
# r7_zip5             0.172118
# r8_zip5             0.135723
# r9_zip5             0.126346
# r1inv_zip5          3.098861
# r2inv_zip5          3.789541
# r3inv_zip5          3.354297
# r4inv_zip5          4.382410
# r5inv_zip5          4.684477
# r6inv_zip5          4.112407
# r7inv_zip5          3.431361
# r8inv_zip5          3.417229
# r9inv_zip5          3.169974
# r1_zip3             0.416685
# r2_zip3             0.471337
# r3_zip3             0.377554
# r4_zip3             0.156409
# r5_zip3             0.058406
# r6_zip3             0.061975
# r7_zip3             0.136762
# r8_zip3             0.044384
# r9_zip3             0.061305
# r1inv_zip3         79.994310
# r2inv_zip3        102.160567
# r3inv_zip3         63.094778
# r4inv_zip3         45.391908
# r5inv_zip3        132.382244
# r6inv_zip3         53.328995
# r7inv_zip3         46.404121
# r8inv_zip3        120.770828
# r9inv_zip3         86.791623
# r1_taxclass         0.341817
# r2_taxclass         0.267622
# r3_taxclass         0.287245
# r4_taxclass         0.301623
# r5_taxclass         0.155195
# r6_taxclass         0.158399
# r7_taxclass         0.338698
# r8_taxclass         0.163033
# r9_taxclass         0.177685
# r1inv_taxclass    192.901011
# r2inv_taxclass    150.935242
# r3inv_taxclass    104.796926
# r4inv_taxclass    153.851665
# r5inv_taxclass    149.143903
# r6inv_taxclass    105.305279
# r7inv_taxclass    151.394783
# r8inv_taxclass    170.167464
# r9inv_taxclass    119.578634
# r1_boro             0.422664
# r2_boro             0.499465
# r3_boro             0.393347
# r4_boro             0.158508
# r5_boro             0.058319
# r6_boro             0.062335
# r7_boro             0.137422
# r8_boro             0.045596
# r9_boro             0.063585
# r1inv_boro         59.342426
# r2inv_boro         78.490958
# r3inv_boro         46.402330
# r4inv_boro         44.081936
# r5inv_boro        109.304763
# r6inv_boro         44.181253
# r7inv_boro         45.805818
# r8inv_boro        119.850219
# r9inv_boro         85.765770
# Name: 7033, dtype: float64

# %%
NY_data_top_n.loc[995567]
# Out:
# BBLE              5028730105
# BORO                       5
# BLOCK                   2873
# LOT                      105
# EASEMENT                 NaN
# OWNER                    NaN
# BLDGCL                    Z7
# TAXCLASS                   4
# LTFRONT                  100
# LTDEPTH                  200
# EXT                      NaN
# STORIES                  NaN
# FULLVAL                 10.0
# AVLAND                  10.0
# AVTOT                   10.0
# EXLAND                   0.0
# EXTOT                    0.0
# EXCD1                    NaN
# STADDR         BURGUNDY LOOP
# ZIP                      NaN
# EXMPTCL                  NaN
# BLDFRONT                   0
# BLDDEPTH                   0
# AVLAND2                  NaN
# AVTOT2                   NaN
# EXLAND2                  NaN
# EXTOT2                   NaN
# EXCD2                    NaN
# PERIOD                 FINAL
# YEAR                 2010/11
# VALTYPE                AC-TR
# score1 rank        1046809.0
# score2 rank        1046809.0
# final              1046809.0
# Name: 995567, dtype: object

# %% [markdown]
# #### 111420

# %%
record_inv = 111420

# %%
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
# Out:
# r1                  0.321199
# r2                  0.522084
# r3                  0.489316
# r4                  0.102637
# r5                  0.060280
# r6                  0.056308
# r7                  0.037787
# r8                  0.054130
# r9                  0.058326
# r1inv               0.015437
# r2inv              78.691122
# r3inv             251.532644
# r4inv               0.012427
# r5inv             137.338616
# r6inv             249.306906
# r7inv               0.004347
# r8inv              60.152932
# r9inv             280.601668
# r1_zip5             0.426677
# r2_zip5             0.469001
# r3_zip5             0.366533
# r4_zip5             0.180747
# r5_zip5             0.122415
# r6_zip5             0.099852
# r7_zip5             0.145980
# r8_zip5             0.135722
# r9_zip5             0.126347
# r1inv_zip5          0.040810
# r2inv_zip5         96.930662
# r3inv_zip5        120.769262
# r4inv_zip5          0.055616
# r5inv_zip5        129.450464
# r6inv_zip5        155.603819
# r7inv_zip5          0.045602
# r8inv_zip5         87.979551
# r9inv_zip5        115.768158
# r1_zip3             0.368652
# r2_zip3             0.471335
# r3_zip3             0.377554
# r4_zip3             0.141628
# r5_zip3             0.058406
# r6_zip3             0.061975
# r7_zip3             0.109473
# r8_zip3             0.044383
# r9_zip3             0.061305
# r1inv_zip3          0.021072
# r2inv_zip3         46.232183
# r3inv_zip3         68.114004
# r4inv_zip3          0.018261
# r5inv_zip3         86.211474
# r6inv_zip3         82.860132
# r7inv_zip3          0.014344
# r8inv_zip3         67.479422
# r9inv_zip3        115.685334
# r1_taxclass         0.170100
# r2_taxclass         0.267617
# r3_taxclass         0.287245
# r4_taxclass         0.196155
# r5_taxclass         0.155193
# r6_taxclass         0.158399
# r7_taxclass         0.168549
# r8_taxclass         0.163031
# r9_taxclass         0.177685
# r1inv_taxclass      0.063525
# r2inv_taxclass     68.303322
# r3inv_taxclass    113.132773
# r4inv_taxclass      0.070908
# r5inv_taxclass     97.126185
# r6inv_taxclass    163.605465
# r7inv_taxclass      0.058653
# r8inv_taxclass     95.077732
# r9inv_taxclass    159.382621
# r1_boro             0.372649
# r2_boro             0.499463
# r3_boro             0.393347
# r4_boro             0.142963
# r5_boro             0.058319
# r6_boro             0.062335
# r7_boro             0.109113
# r8_boro             0.045595
# r9_boro             0.063585
# r1inv_boro          0.015745
# r2inv_boro         35.520584
# r3inv_boro         50.093666
# r4inv_boro          0.017805
# r5inv_boro         71.182804
# r6inv_boro         68.646748
# r7inv_boro          0.014322
# r8inv_boro         66.964902
# r9inv_boro        114.318045
# Name: 111420, dtype: float64

# %%
NY_data_top_n.loc[record_inv]
# Out:
# BBLE                      1015101092
# BORO                               1
# BLOCK                           1510
# LOT                             1092
# EASEMENT                         NaN
# OWNER          BOXWOOD FLTD PARNTERS
# BLDGCL                            R4
# TAXCLASS                           2
# LTFRONT                           75
# LTDEPTH                           93
# EXT                              NaN
# STORIES                         31.0
# FULLVAL                     296508.0
# AVLAND                       22896.0
# AVTOT                       133429.0
# EXLAND                           0.0
# EXTOT                            0.0
# EXCD1                            NaN
# STADDR                 1438 3 AVENUE
# ZIP                          10028.0
# EXMPTCL                          NaN
# BLDFRONT                        7575
# BLDDEPTH                        9393
# AVLAND2                      22896.0
# AVTOT2                      146183.0
# EXLAND2                          NaN
# EXTOT2                           NaN
# EXCD2                            NaN
# PERIOD                         FINAL
# YEAR                         2010/11
# VALTYPE                        AC-TR
# score1 rank                1046793.0
# score2 rank                1046719.0
# final                      1046756.0
# Name: 111420, dtype: object

# %%
# looks like a typing mistake maybe - BLDFRONT, BLDDEPTH have repeated values - 7575 
#instead of maybe 75 and 9393 instead of maybe 93

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Building bigger than the lot

# %% [markdown]
# #### 64271

# %%
record_inv = 994769

# %%
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
# Out:
# r1                21.474658
# r2                 0.018365
# r3                 0.301263
# r4                26.570114
# r5                 0.159162
# r6                 0.028113
# r7                26.541591
# r8                 0.205013
# r9                 0.075565
# r1inv              0.019474
# r2inv              0.024458
# r3inv              0.027630
# r4inv              0.014903
# r5inv              0.045862
# r6inv              0.033934
# r7inv              0.004788
# r8inv              0.038721
# r9inv              0.041331
# r1_zip5           27.478948
# r2_zip5            0.046425
# r3_zip5            0.236116
# r4_zip5           23.641893
# r5_zip5            0.432511
# r6_zip5            0.043733
# r7_zip5           23.222183
# r8_zip5            0.870693
# r9_zip5            0.173060
# r1inv_zip5         0.049760
# r2inv_zip5         0.060398
# r3inv_zip5         0.054932
# r4inv_zip5         0.070261
# r5inv_zip5         0.074864
# r6inv_zip5         0.068170
# r7inv_zip5         0.055564
# r8inv_zip5         0.055244
# r9inv_zip5         0.052940
# r1_zip3           31.410094
# r2_zip3            0.050228
# r3_zip3            0.238877
# r4_zip3           32.613657
# r5_zip3            0.204162
# r6_zip3            0.030437
# r7_zip3           34.450605
# r8_zip3            0.293519
# r9_zip3            0.092493
# r1inv_zip3         0.023383
# r2inv_zip3         0.028729
# r3inv_zip3         0.028097
# r4inv_zip3         0.020152
# r5inv_zip3         0.061417
# r6inv_zip3         0.040502
# r7inv_zip3         0.016005
# r8inv_zip3         0.040181
# r9inv_zip3         0.046322
# r1_taxclass       14.885739
# r2_taxclass        0.083583
# r3_taxclass        0.104066
# r4_taxclass       12.593046
# r5_taxclass        0.008907
# r6_taxclass        0.090632
# r7_taxclass       15.192691
# r8_taxclass        0.048529
# r9_taxclass        0.065076
# r1inv_taxclass     0.069113
# r2inv_taxclass     0.045545
# r3inv_taxclass     0.036861
# r4inv_taxclass     0.077327
# r5inv_taxclass     0.072747
# r6inv_taxclass     0.057648
# r7inv_taxclass     0.064068
# r8inv_taxclass     0.060139
# r9inv_taxclass     0.049605
# r1_boro           31.860811
# r2_boro            0.053225
# r3_boro            0.248869
# r4_boro           33.051315
# r5_boro            0.203858
# r6_boro            0.030613
# r7_boro           34.616807
# r8_boro            0.301533
# r9_boro            0.095933
# r1inv_boro         0.017459
# r2inv_boro         0.022168
# r3inv_boro         0.020719
# r4inv_boro         0.019641
# r5inv_boro         0.050399
# r6inv_boro         0.033476
# r7inv_boro         0.015961
# r8inv_boro         0.040191
# r9inv_boro         0.046010
# Name: 994769, dtype: float64

# %%
NY_data_top_n.loc[record_inv]
# Out:
# BBLE           5028590165E
# BORO                     5
# BLOCK                 2859
# LOT                    165
# EASEMENT                 E
# OWNER                  NaN
# BLDGCL                  Z7
# TAXCLASS                 4
# LTFRONT                 17
# LTDEPTH                 14
# EXT                    NaN
# STORIES                NaN
# FULLVAL                0.0
# AVLAND                 0.0
# AVTOT                  0.0
# EXLAND                 0.0
# EXTOT                  0.0
# EXCD1                  NaN
# STADDR         DAYNA DRIVE
# ZIP                10305.0
# EXMPTCL                NaN
# BLDFRONT                 0
# BLDDEPTH                 0
# AVLAND2                NaN
# AVTOT2                 NaN
# EXLAND2                NaN
# EXTOT2                 NaN
# EXCD2                  NaN
# PERIOD               FINAL
# YEAR               2010/11
# VALTYPE              AC-TR
# score1 rank      1046189.5
# score2 rank      1045153.5
# final            1045671.5
# Name: 994769, dtype: object

# %%
# missing values - LTFRONT, LTDEPTH

# %% [markdown]
# ### There were many records with LTFRONT, LTDEPTH, BLDFRONT or BLDDEPTH as 0

# %%
# interesting_indexes are those which have non-zero such values
data_to_inv = NY_data_top_n.loc[interesting_indexes]

# %%
data_to_inv[cols_to_check]
# Out:
#         LTFRONT  LTDEPTH  BLDFRONT  BLDDEPTH  STORIES
# RECORD
# 333412       17       85      4017        42      3.0
# 665157      981     2663        40        25      1.0
# 665158     1412     2532        12        18      1.0
# 111420       75       93      7575      9393     31.0
# 956520       25       91      1812      5020      3.0
# 934780      540      345        30        40      1.0
# 934793     2798      997        30        40      1.0
# 116647       25       75        70       456     35.0
# 12076        74      150         5         5      1.0
# 817296     1114      720        20        28      1.0
# 638993      379      205         6         5      1.0
# 243059      999      556        16        30      1.0
# 330292       60      540         3         5      1.0
# 980276      278      190        15        30      1.0
# 658933       25      100      2500      5600      3.0
# 973912     2800     3700         2        12      2.0
# 33564       380      184         8        12      1.0

# %% [markdown]
# {41924,
#  52020,
#  111420,
#  243061,
#  264421,
#  280232,
#  643751,
#  680798,
#  748180,
#  826511,
#  1062743, }

# %%
(NY_data_with_scores.LTFRONT.mean() / NY_data_with_scores.BLDFRONT.mean())
# Out:
# 1.589882727868457

# %% [markdown]
# #### 111420

# %%
record_inv = 111420

# %%
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
# Out:
# r1                  0.321199
# r2                  0.522084
# r3                  0.489316
# r4                  0.102637
# r5                  0.060280
# r6                  0.056308
# r7                  0.037787
# r8                  0.054130
# r9                  0.058326
# r1inv               0.015437
# r2inv              78.691122
# r3inv             251.532644
# r4inv               0.012427
# r5inv             137.338616
# r6inv             249.306906
# r7inv               0.004347
# r8inv              60.152932
# r9inv             280.601668
# r1_zip5             0.426677
# r2_zip5             0.469001
# r3_zip5             0.366533
# r4_zip5             0.180747
# r5_zip5             0.122415
# r6_zip5             0.099852
# r7_zip5             0.145980
# r8_zip5             0.135722
# r9_zip5             0.126347
# r1inv_zip5          0.040810
# r2inv_zip5         96.930662
# r3inv_zip5        120.769262
# r4inv_zip5          0.055616
# r5inv_zip5        129.450464
# r6inv_zip5        155.603819
# r7inv_zip5          0.045602
# r8inv_zip5         87.979551
# r9inv_zip5        115.768158
# r1_zip3             0.368652
# r2_zip3             0.471335
# r3_zip3             0.377554
# r4_zip3             0.141628
# r5_zip3             0.058406
# r6_zip3             0.061975
# r7_zip3             0.109473
# r8_zip3             0.044383
# r9_zip3             0.061305
# r1inv_zip3          0.021072
# r2inv_zip3         46.232183
# r3inv_zip3         68.114004
# r4inv_zip3          0.018261
# r5inv_zip3         86.211474
# r6inv_zip3         82.860132
# r7inv_zip3          0.014344
# r8inv_zip3         67.479422
# r9inv_zip3        115.685334
# r1_taxclass         0.170100
# r2_taxclass         0.267617
# r3_taxclass         0.287245
# r4_taxclass         0.196155
# r5_taxclass         0.155193
# r6_taxclass         0.158399
# r7_taxclass         0.168549
# r8_taxclass         0.163031
# r9_taxclass         0.177685
# r1inv_taxclass      0.063525
# r2inv_taxclass     68.303322
# r3inv_taxclass    113.132773
# r4inv_taxclass      0.070908
# r5inv_taxclass     97.126185
# r6inv_taxclass    163.605465
# r7inv_taxclass      0.058653
# r8inv_taxclass     95.077732
# r9inv_taxclass    159.382621
# r1_boro             0.372649
# r2_boro             0.499463
# r3_boro             0.393347
# r4_boro             0.142963
# r5_boro             0.058319
# r6_boro             0.062335
# r7_boro             0.109113
# r8_boro             0.045595
# r9_boro             0.063585
# r1inv_boro          0.015745
# r2inv_boro         35.520584
# r3inv_boro         50.093666
# r4inv_boro          0.017805
# r5inv_boro         71.182804
# r6inv_boro         68.646748
# r7inv_boro          0.014322
# r8inv_boro         66.964902
# r9inv_boro        114.318045
# Name: 111420, dtype: float64

# %%
NY_data_top_n.loc[record_inv]
# Out:
# BBLE                      1015101092
# BORO                               1
# BLOCK                           1510
# LOT                             1092
# EASEMENT                         NaN
# OWNER          BOXWOOD FLTD PARNTERS
# BLDGCL                            R4
# TAXCLASS                           2
# LTFRONT                           75
# LTDEPTH                           93
# EXT                              NaN
# STORIES                         31.0
# FULLVAL                     296508.0
# AVLAND                       22896.0
# AVTOT                       133429.0
# EXLAND                           0.0
# EXTOT                            0.0
# EXCD1                            NaN
# STADDR                 1438 3 AVENUE
# ZIP                          10028.0
# EXMPTCL                          NaN
# BLDFRONT                        7575
# BLDDEPTH                        9393
# AVLAND2                      22896.0
# AVTOT2                      146183.0
# EXLAND2                          NaN
# EXTOT2                           NaN
# EXCD2                            NaN
# PERIOD                         FINAL
# YEAR                         2010/11
# VALTYPE                        AC-TR
# score1 rank                1046793.0
# score2 rank                1046719.0
# final                      1046756.0
# Name: 111420, dtype: object

# %%
# looks like a typing mistake maybe - BLDFRONT, BLDDEPTH have repeated values - 7575 instead of maybe 75 and 9393 instead of maybe 93

# %% [markdown]
# #### 826511

# %% [markdown]
# #### 826511

# %%
record_inv = 994769
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
# Out:
# r1                21.474658
# r2                 0.018365
# r3                 0.301263
# r4                26.570114
# r5                 0.159162
# r6                 0.028113
# r7                26.541591
# r8                 0.205013
# r9                 0.075565
# r1inv              0.019474
# r2inv              0.024458
# r3inv              0.027630
# r4inv              0.014903
# r5inv              0.045862
# r6inv              0.033934
# r7inv              0.004788
# r8inv              0.038721
# r9inv              0.041331
# r1_zip5           27.478948
# r2_zip5            0.046425
# r3_zip5            0.236116
# r4_zip5           23.641893
# r5_zip5            0.432511
# r6_zip5            0.043733
# r7_zip5           23.222183
# r8_zip5            0.870693
# r9_zip5            0.173060
# r1inv_zip5         0.049760
# r2inv_zip5         0.060398
# r3inv_zip5         0.054932
# r4inv_zip5         0.070261
# r5inv_zip5         0.074864
# r6inv_zip5         0.068170
# r7inv_zip5         0.055564
# r8inv_zip5         0.055244
# r9inv_zip5         0.052940
# r1_zip3           31.410094
# r2_zip3            0.050228
# r3_zip3            0.238877
# r4_zip3           32.613657
# r5_zip3            0.204162
# r6_zip3            0.030437
# r7_zip3           34.450605
# r8_zip3            0.293519
# r9_zip3            0.092493
# r1inv_zip3         0.023383
# r2inv_zip3         0.028729
# r3inv_zip3         0.028097
# r4inv_zip3         0.020152
# r5inv_zip3         0.061417
# r6inv_zip3         0.040502
# r7inv_zip3         0.016005
# r8inv_zip3         0.040181
# r9inv_zip3         0.046322
# r1_taxclass       14.885739
# r2_taxclass        0.083583
# r3_taxclass        0.104066
# r4_taxclass       12.593046
# r5_taxclass        0.008907
# r6_taxclass        0.090632
# r7_taxclass       15.192691
# r8_taxclass        0.048529
# r9_taxclass        0.065076
# r1inv_taxclass     0.069113
# r2inv_taxclass     0.045545
# r3inv_taxclass     0.036861
# r4inv_taxclass     0.077327
# r5inv_taxclass     0.072747
# r6inv_taxclass     0.057648
# r7inv_taxclass     0.064068
# r8inv_taxclass     0.060139
# r9inv_taxclass     0.049605
# r1_boro           31.860811
# r2_boro            0.053225
# r3_boro            0.248869
# r4_boro           33.051315
# r5_boro            0.203858
# r6_boro            0.030613
# r7_boro           34.616807
# r8_boro            0.301533
# r9_boro            0.095933
# r1inv_boro         0.017459
# r2inv_boro         0.022168
# r3inv_boro         0.020719
# r4inv_boro         0.019641
# r5inv_boro         0.050399
# r6inv_boro         0.033476
# r7inv_boro         0.015961
# r8inv_boro         0.040191
# r9inv_boro         0.046010
# Name: 994769, dtype: float64

# %% [markdown]
# #### Heatmap of interesting data

# %%
data_heatmap = data_zs_top_n_abs.loc[interesting_indexes]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
interesting_indexes
# Out:
# {12076,
#  33564,
#  111420,
#  116647,
#  243059,
#  330292,
#  333412,
#  638993,
#  658933,
#  665157,
#  665158,
#  817296,
#  934780,
#  934793,
#  956520,
#  973912,
#  980276}

# %%
(data_zs_top_n > 500).sum(axis=1).sum()
# Out:
# 50

# %%
cols_to_check
# Out:
# ['LTFRONT', 'LTDEPTH', 'BLDFRONT', 'BLDDEPTH', 'STORIES']

# %%
values_of_interest = ['FULLVAL', 'AVLAND', 'AVTOT']
values_of_interest.extend(cols_to_check)
values_of_interest
# Out:
# ['FULLVAL',
#  'AVLAND',
#  'AVTOT',
#  'LTFRONT',
#  'LTDEPTH',
#  'BLDFRONT',
#  'BLDDEPTH',
#  'STORIES']

# %%
## Report on interesting records

for i in interesting_indexes:
    print('-'*40)
    print(i)
    print('-'*40)
    print(NY_data_with_scores.loc[i, values_of_interest])
# Out:
# ----------------------------------------
# 333412
# ----------------------------------------
# FULLVAL     9060.0
# AVLAND      3874.0
# AVTOT       4077.0
# LTFRONT         17
# LTDEPTH         85
# BLDFRONT      4017
# BLDDEPTH        42
# STORIES        3.0
# Name: 333412, dtype: object
# ----------------------------------------
# 665157
# ----------------------------------------
# FULLVAL     106100000.0
# AVLAND       35010000.0
# AVTOT        47745000.0
# LTFRONT             981
# LTDEPTH            2663
# BLDFRONT             40
# BLDDEPTH             25
# STORIES             1.0
# Name: 665157, dtype: object
# ----------------------------------------
# 665158
# ----------------------------------------
# FULLVAL     29355000.0
# AVLAND      13140000.0
# AVTOT       13209750.0
# LTFRONT           1412
# LTDEPTH           2532
# BLDFRONT            12
# BLDDEPTH            18
# STORIES            1.0
# Name: 665158, dtype: object
# ----------------------------------------
# 111420
# ----------------------------------------
# FULLVAL     296508.0
# AVLAND       22896.0
# AVTOT       133429.0
# LTFRONT           75
# LTDEPTH           93
# BLDFRONT        7575
# BLDDEPTH        9393
# STORIES         31.0
# Name: 111420, dtype: object
# ----------------------------------------
# 956520
# ----------------------------------------
# FULLVAL     348200.0
# AVLAND       15600.0
# AVTOT        20892.0
# LTFRONT           25
# LTDEPTH           91
# BLDFRONT        1812
# BLDDEPTH        5020
# STORIES          3.0
# Name: 956520, dtype: object
# ----------------------------------------
# 934780
# ----------------------------------------
# FULLVAL     82400000.0
# AVLAND       2874000.0
# AVTOT        4944000.0
# LTFRONT            540
# LTDEPTH            345
# BLDFRONT            30
# BLDDEPTH            40
# STORIES            1.0
# Name: 934780, dtype: object
# ----------------------------------------
# 934793
# ----------------------------------------
# FULLVAL     273000000.0
# AVLAND       10920000.0
# AVTOT        16380000.0
# LTFRONT            2798
# LTDEPTH             997
# BLDFRONT             30
# BLDDEPTH             40
# STORIES             1.0
# Name: 934793, dtype: object
# ----------------------------------------
# 116647
# ----------------------------------------
# FULLVAL     161000000.0
# AVLAND       19215000.0
# AVTOT        72450000.0
# LTFRONT              25
# LTDEPTH              75
# BLDFRONT             70
# BLDDEPTH            456
# STORIES            35.0
# Name: 116647, dtype: object
# ----------------------------------------
# 12076
# ----------------------------------------
# FULLVAL     2610000.0
# AVLAND      1170000.0
# AVTOT       1174500.0
# LTFRONT            74
# LTDEPTH           150
# BLDFRONT            5
# BLDDEPTH            5
# STORIES           1.0
# Name: 12076, dtype: object
# ----------------------------------------
# 817296
# ----------------------------------------
# FULLVAL     40400000.0
# AVLAND      18000000.0
# AVTOT       18180000.0
# LTFRONT           1114
# LTDEPTH            720
# BLDFRONT            20
# BLDDEPTH            28
# STORIES            1.0
# Name: 817296, dtype: object
# ----------------------------------------
# 638993
# ----------------------------------------
# FULLVAL     2328900.0
# AVLAND      1013220.0
# AVTOT       1048005.0
# LTFRONT           379
# LTDEPTH           205
# BLDFRONT            6
# BLDDEPTH            5
# STORIES           1.0
# Name: 638993, dtype: object
# ----------------------------------------
# 243059
# ----------------------------------------
# FULLVAL     55860000.0
# AVLAND       1217059.0
# AVTOT        2258636.0
# LTFRONT            999
# LTDEPTH            556
# BLDFRONT            16
# BLDDEPTH            30
# STORIES            1.0
# Name: 243059, dtype: object
# ----------------------------------------
# 330292
# ----------------------------------------
# FULLVAL     1016250.0
# AVLAND       454500.0
# AVTOT        457313.0
# LTFRONT            60
# LTDEPTH           540
# BLDFRONT            3
# BLDDEPTH            5
# STORIES           1.0
# Name: 330292, dtype: object
# ----------------------------------------
# 980276
# ----------------------------------------
# FULLVAL     3670.0
# AVLAND        89.0
# AVTOT         92.0
# LTFRONT        278
# LTDEPTH        190
# BLDFRONT        15
# BLDDEPTH        30
# STORIES        1.0
# Name: 980276, dtype: object
# ----------------------------------------
# 658933
# ----------------------------------------
# FULLVAL     776000.0
# AVLAND       26940.0
# AVTOT        46560.0
# LTFRONT           25
# LTDEPTH          100
# BLDFRONT        2500
# BLDDEPTH        5600
# STORIES          3.0
# Name: 658933, dtype: object
# ----------------------------------------
# 973912
# ----------------------------------------
# FULLVAL     3090000.0
# AVLAND      1309500.0
# AVTOT       1390500.0
# LTFRONT          2800
# LTDEPTH          3700
# BLDFRONT            2
# BLDDEPTH           12
# STORIES           2.0
# Name: 973912, dtype: object
# ----------------------------------------
# 33564
# ----------------------------------------
# FULLVAL     8005000.0
# AVLAND      3600000.0
# AVTOT       3602250.0
# LTFRONT           380
# LTDEPTH           184
# BLDFRONT            8
# BLDDEPTH           12
# STORIES           1.0
# Name: 33564, dtype: object

# %% [markdown]
# ____

# %% [markdown]
# {12076,
#  33564,
#  111420,
#  116647,
#  243059,
#  330292,
#  333412,
#  638993,
#  658933,
#  665157,
#  665158,
#  817296,
#  934780,
#  934793,
#  956520,
#  973912,
#  980276}

# %%
NY_data_with_scores.loc[33564]
# Out:
# BBLE                    1006890017
# BORO                             1
# BLOCK                          689
# LOT                             17
# EASEMENT                       NaN
# OWNER          HLP PROPERTIES, LLC
# BLDGCL                          G6
# TAXCLASS                         4
# LTFRONT                        380
# LTDEPTH                        184
# EXT                            NaN
# STORIES                        1.0
# FULLVAL                  8005000.0
# AVLAND                   3600000.0
# AVTOT                    3602250.0
# EXLAND                         0.0
# EXTOT                          0.0
# EXCD1                          NaN
# STADDR          501 WEST 17 STREET
# ZIP                        10011.0
# EXMPTCL                        NaN
# BLDFRONT                         8
# BLDDEPTH                        12
# AVLAND2                  2956545.0
# AVTOT2                   2958795.0
# EXLAND2                        NaN
# EXTOT2                         NaN
# EXCD2                          NaN
# PERIOD                       FINAL
# YEAR                       2010/11
# VALTYPE                      AC-TR
# score1 rank              1046794.0
# score2 rank              1046528.0
# final                    1046661.0
# Name: 33564, dtype: object

# %%
NY_data_with_scores.loc[111420]
# Out:
# BBLE                      1015101092
# BORO                               1
# BLOCK                           1510
# LOT                             1092
# EASEMENT                         NaN
# OWNER          BOXWOOD FLTD PARNTERS
# BLDGCL                            R4
# TAXCLASS                           2
# LTFRONT                           75
# LTDEPTH                           93
# EXT                              NaN
# STORIES                         31.0
# FULLVAL                     296508.0
# AVLAND                       22896.0
# AVTOT                       133429.0
# EXLAND                           0.0
# EXTOT                            0.0
# EXCD1                            NaN
# STADDR                 1438 3 AVENUE
# ZIP                          10028.0
# EXMPTCL                          NaN
# BLDFRONT                        7575
# BLDDEPTH                        9393
# AVLAND2                      22896.0
# AVTOT2                      146183.0
# EXLAND2                          NaN
# EXTOT2                           NaN
# EXCD2                            NaN
# PERIOD                         FINAL
# YEAR                         2010/11
# VALTYPE                        AC-TR
# score1 rank                1046793.0
# score2 rank                1046719.0
# final                      1046756.0
# Name: 111420, dtype: object

# %%
NY_data_with_scores.loc[817296]
# Out:
# BBLE                       4096310048
# BORO                                4
# BLOCK                            9631
# LOT                                48
# EASEMENT                          NaN
# OWNER           NEW YORK STATE DEPART
# BLDGCL                             Z8
# TAXCLASS                            4
# LTFRONT                          1114
# LTDEPTH                           720
# EXT                               NaN
# STORIES                           1.0
# FULLVAL                    40400000.0
# AVLAND                     18000000.0
# AVTOT                      18180000.0
# EXLAND                     18000000.0
# EXTOT                      18180000.0
# EXCD1                          1700.0
# STADDR         83-15 KEW GARDENS ROAD
# ZIP                           11415.0
# EXMPTCL                            X5
# BLDFRONT                           20
# BLDDEPTH                           28
# AVLAND2                           NaN
# AVTOT2                            NaN
# EXLAND2                           NaN
# EXTOT2                            NaN
# EXCD2                             NaN
# PERIOD                          FINAL
# YEAR                          2010/11
# VALTYPE                         AC-TR
# score1 rank                 1046779.0
# score2 rank                 1046521.0
# final                       1046650.0
# Name: 817296, dtype: object

# %%
record_inv = 956520
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
NY_data_with_scores.loc[record_inv]
# Out:
# r1                  0.113628
# r2                  0.522051
# r3                  0.489290
# r4                  0.051554
# r5                  0.060277
# r6                  0.056305
# r7                  0.086573
# r8                  0.054130
# r9                  0.058324
# r1inv               0.018363
# r2inv               8.544237
# r3inv               2.622248
# r4inv               0.013720
# r5inv              25.731612
# r6inv               4.493444
# r7inv               0.003868
# r8inv              49.106431
# r9inv              22.133072
# r1_zip5             0.175538
# r2_zip5             0.468962
# r3_zip5             0.366512
# r4_zip5             0.026468
# r5_zip5             0.122404
# r6_zip5             0.099846
# r7_zip5             0.062046
# r8_zip5             0.135714
# r9_zip5             0.126341
# r1inv_zip5          0.049407
# r2inv_zip5         24.911294
# r3inv_zip5          6.349271
# r4inv_zip5          0.067695
# r5inv_zip5         58.209776
# r6inv_zip5         27.278706
# r7inv_zip5          0.052983
# r8inv_zip5         55.629306
# r9inv_zip5         27.021113
# r1_zip3             0.001439
# r2_zip3             0.471301
# r3_zip3             0.377536
# r4_zip3             0.036227
# r5_zip3             0.058401
# r6_zip3             0.061972
# r7_zip3             0.078354
# r8_zip3             0.044381
# r9_zip3             0.061303
# r1inv_zip3          0.022610
# r2inv_zip3          3.870455
# r3inv_zip3          2.037290
# r4inv_zip3          0.018976
# r5inv_zip3         38.024281
# r6inv_zip3         16.698718
# r7inv_zip3          0.015147
# r8inv_zip3         21.262430
# r9inv_zip3         15.788793
# r1_taxclass         0.113262
# r2_taxclass         0.267611
# r3_taxclass         0.287236
# r4_taxclass         0.058502
# r5_taxclass         0.155182
# r6_taxclass         0.158389
# r7_taxclass         0.016790
# r8_taxclass         0.163024
# r9_taxclass         0.177677
# r1inv_taxclass      0.002003
# r2inv_taxclass    648.455279
# r3inv_taxclass    753.597262
# r4inv_taxclass      0.031215
# r5inv_taxclass    586.352291
# r6inv_taxclass    657.333470
# r7inv_taxclass      0.015738
# r8inv_taxclass    625.536220
# r9inv_taxclass    736.753067
# r1_boro             0.001460
# r2_boro             0.499426
# r3_boro             0.393327
# r4_boro             0.036713
# r5_boro             0.058314
# r6_boro             0.062332
# r7_boro             0.078732
# r8_boro             0.045593
# r9_boro             0.063583
# r1inv_boro          0.016882
# r2inv_boro          2.986507
# r3inv_boro          1.502301
# r4inv_boro          0.018495
# r5inv_boro         31.202957
# r6inv_boro         13.801822
# r7inv_boro          0.015106
# r8inv_boro         21.267255
# r9inv_boro         15.682684
# Name: 956520, dtype: float64
# BBLE                  5006590012
# BORO                           5
# BLOCK                        659
# LOT                           12
# EASEMENT                     NaN
# OWNER          TROMPETA RIZALINA
# BLDGCL                        A1
# TAXCLASS                       1
# LTFRONT                       25
# LTDEPTH                       91
# EXT                            G
# STORIES                      3.0
# FULLVAL                 348200.0
# AVLAND                   15600.0
# AVTOT                    20892.0
# EXLAND                    1620.0
# EXTOT                     1620.0
# EXCD1                     1017.0
# STADDR          12 ONEIDA AVENUE
# ZIP                      10301.0
# EXMPTCL                      NaN
# BLDFRONT                    1812
# BLDDEPTH                    5020
# AVLAND2                      NaN
# AVTOT2                       NaN
# EXLAND2                      NaN
# EXTOT2                       NaN
# EXCD2                        NaN
# PERIOD                     FINAL
# YEAR                     2010/11
# VALTYPE                    AC-TR
# score1 rank            1046823.0
# score2 rank            1046798.0
# final                  1046810.5
# Name: 956520, dtype: object

# %%
record_inv = 243059
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
NY_data_with_scores.loc[record_inv]

# incomplete address
# 
#
# Out:
# r1                  0.212183
# r2                112.744538
# r3                232.809852
# r4                  0.118234
# r5                  6.638520
# r6                 14.162049
# r7                  0.111672
# r8                  4.993595
# r9                 14.330511
# r1inv               0.017776
# r2inv               0.025089
# r3inv               0.027990
# r4inv               0.011191
# r5inv               0.046377
# r6inv               0.034105
# r7inv               0.002708
# r8inv               0.039164
# r9inv               0.041715
# r1_zip5             0.138296
# r2_zip5            98.074817
# r3_zip5           132.554292
# r4_zip5             0.119246
# r5_zip5            15.494436
# r6_zip5            21.767847
# r7_zip5             0.103374
# r8_zip5            18.222048
# r9_zip5            29.380359
# r1inv_zip5          0.041448
# r2inv_zip5          0.060921
# r3inv_zip5          0.055441
# r4inv_zip5          0.056824
# r5inv_zip5          0.075542
# r6inv_zip5          0.068972
# r7inv_zip5          0.039841
# r8inv_zip5          0.055407
# r9inv_zip5          0.053165
# r1_zip3             0.125271
# r2_zip3           133.103744
# r3_zip3           216.462742
# r4_zip3             0.099543
# r5_zip3             8.307701
# r6_zip3            15.465327
# r7_zip3             0.102809
# r8_zip3             5.214246
# r9_zip3            14.758190
# r1inv_zip3          0.021093
# r2inv_zip3          0.029013
# r3inv_zip3          0.028377
# r4inv_zip3          0.013543
# r5inv_zip3          0.062168
# r6inv_zip3          0.041134
# r7inv_zip3          0.007612
# r8inv_zip3          0.040361
# r9inv_zip3          0.046593
# r1_taxclass         0.010282
# r2_taxclass         0.898456
# r3_taxclass         0.977300
# r4_taxclass         0.043097
# r5_taxclass         0.352849
# r6_taxclass         0.364155
# r7_taxclass         0.040778
# r8_taxclass         0.421744
# r9_taxclass         0.465010
# r1inv_taxclass      0.021275
# r2inv_taxclass      0.044256
# r3inv_taxclass      0.035829
# r4inv_taxclass      0.019098
# r5inv_taxclass      0.070222
# r6inv_taxclass      0.055668
# r7inv_taxclass      0.016263
# r8inv_taxclass      0.058137
# r9inv_taxclass      0.047994
# r1_boro             0.126694
# r2_boro           141.108548
# r3_boro           225.493637
# r4_boro             0.100779
# r5_boro             8.296656
# r6_boro            15.554369
# r7_boro             0.103247
# r8_boro             5.359610
# r9_boro            15.313878
# r1inv_boro          0.015752
# r2inv_boro          0.022387
# r3inv_boro          0.020926
# r4inv_boro          0.013204
# r5inv_boro          0.051015
# r6inv_boro          0.033998
# r7inv_boro          0.007606
# r8inv_boro          0.040370
# r9inv_boro          0.046280
# Name: 243059, dtype: float64
# BBLE                     2055060001
# BORO                              2
# BLOCK                          5506
# LOT                               1
# EASEMENT                        NaN
# OWNER          SILVER BEACH GARDENS
# BLDGCL                           A8
# TAXCLASS                         1D
# LTFRONT                         999
# LTDEPTH                         556
# EXT                             NaN
# STORIES                         1.0
# FULLVAL                  55860000.0
# AVLAND                    1217059.0
# AVTOT                     2258636.0
# EXLAND                     403350.0
# EXTOT                      403350.0
# EXCD1                        1010.0
# STADDR                 SILVER BEACH
# ZIP                         10465.0
# EXMPTCL                         NaN
# BLDFRONT                         16
# BLDDEPTH                         30
# AVLAND2                         NaN
# AVTOT2                          NaN
# EXLAND2                         NaN
# EXTOT2                          NaN
# EXCD2                        1015.0
# PERIOD                        FINAL
# YEAR                        2010/11
# VALTYPE                       AC-TR
# score1 rank               1046788.0
# score2 rank               1046797.0
# final                     1046792.5
# Name: 243059, dtype: object

# %%
record_inv = 12076
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
NY_data_with_scores.loc[record_inv]
# Out:
# r1                  0.040495
# r2                101.089390
# r3                208.803343
# r4                  1.356764
# r5                123.583567
# r6                262.380577
# r7                  0.387384
# r8                 50.342778
# r9                143.600959
# r1inv               0.018756
# r2inv               0.025089
# r3inv               0.027990
# r4inv               0.014831
# r5inv               0.046394
# r6inv               0.034106
# r7inv               0.004710
# r8inv               0.039186
# r9inv               0.041718
# r1_zip5             0.116247
# r2_zip5           119.212119
# r3_zip5           350.315317
# r4_zip5             0.614559
# r5_zip5           134.696814
# r6_zip5           239.233083
# r7_zip5             0.055414
# r8_zip5            57.998112
# r9_zip5           187.368728
# r1inv_zip5          0.048701
# r2inv_zip5          0.060950
# r3inv_zip5          0.055448
# r4inv_zip5          0.070120
# r5inv_zip5          0.075592
# r6inv_zip5          0.068986
# r7inv_zip5          0.054383
# r8inv_zip5          0.055436
# r9inv_zip5          0.053173
# r1_zip3             0.150997
# r2_zip3            92.272658
# r3_zip3           344.065240
# r4_zip3             0.318253
# r5_zip3            55.472523
# r6_zip3           267.224952
# r7_zip3             0.014188
# r8_zip3            15.724067
# r9_zip3           127.506009
# r1inv_zip3          0.022974
# r2inv_zip3          0.029016
# r3inv_zip3          0.028378
# r4inv_zip3          0.020097
# r5inv_zip3          0.062202
# r6inv_zip3          0.041138
# r7inv_zip3          0.015706
# r8inv_zip3          0.040381
# r9inv_zip3          0.046598
# r1_taxclass         0.034485
# r2_taxclass        70.578594
# r3_taxclass       203.584117
# r4_taxclass         0.425305
# r5_taxclass        92.308022
# r6_taxclass       210.509256
# r7_taxclass         0.036498
# r8_taxclass        40.980877
# r9_taxclass       120.648602
# r1inv_taxclass      0.068616
# r2inv_taxclass      0.045726
# r3inv_taxclass      0.036953
# r4inv_taxclass      0.077224
# r5inv_taxclass      0.072969
# r6inv_taxclass      0.057704
# r7inv_taxclass      0.063571
# r8inv_taxclass      0.060387
# r9inv_taxclass      0.049730
# r1_boro             0.146012
# r2_boro           100.176406
# r3_boro           366.548234
# r4_boro             0.340684
# r5_boro            57.409004
# r6_boro           279.222159
# r7_boro             0.019166
# r8_boro            16.688522
# r9_boro           137.081482
# r1inv_boro          0.017156
# r2inv_boro          0.022389
# r3inv_boro          0.020926
# r4inv_boro          0.019588
# r5inv_boro          0.051044
# r6inv_boro          0.034001
# r7inv_boro          0.015666
# r8inv_boro          0.040390
# r9inv_boro          0.046285
# Name: 12076, dtype: float64
# BBLE                      1001790001
# BORO                               1
# BLOCK                            179
# LOT                                1
# EASEMENT                         NaN
# OWNER          15 WORTH STREET PROPE
# BLDGCL                            G6
# TAXCLASS                           4
# LTFRONT                           74
# LTDEPTH                          150
# EXT                              NaN
# STORIES                          1.0
# FULLVAL                    2610000.0
# AVLAND                     1170000.0
# AVTOT                      1174500.0
# EXLAND                           0.0
# EXTOT                            0.0
# EXCD1                            NaN
# STADDR             170 WEST BROADWAY
# ZIP                          10013.0
# EXMPTCL                          NaN
# BLDFRONT                           5
# BLDDEPTH                           5
# AVLAND2                     936900.0
# AVTOT2                      941400.0
# EXLAND2                          NaN
# EXTOT2                           NaN
# EXCD2                            NaN
# PERIOD                         FINAL
# YEAR                         2010/11
# VALTYPE                        AC-TR
# score1 rank                1046816.0
# score2 rank                1046603.0
# final                      1046709.5
# Name: 12076, dtype: object

# %%
record_inv = 956520
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
NY_data_with_scores.loc[record_inv]
# Out:
# r1                  0.113628
# r2                  0.522051
# r3                  0.489290
# r4                  0.051554
# r5                  0.060277
# r6                  0.056305
# r7                  0.086573
# r8                  0.054130
# r9                  0.058324
# r1inv               0.018363
# r2inv               8.544237
# r3inv               2.622248
# r4inv               0.013720
# r5inv              25.731612
# r6inv               4.493444
# r7inv               0.003868
# r8inv              49.106431
# r9inv              22.133072
# r1_zip5             0.175538
# r2_zip5             0.468962
# r3_zip5             0.366512
# r4_zip5             0.026468
# r5_zip5             0.122404
# r6_zip5             0.099846
# r7_zip5             0.062046
# r8_zip5             0.135714
# r9_zip5             0.126341
# r1inv_zip5          0.049407
# r2inv_zip5         24.911294
# r3inv_zip5          6.349271
# r4inv_zip5          0.067695
# r5inv_zip5         58.209776
# r6inv_zip5         27.278706
# r7inv_zip5          0.052983
# r8inv_zip5         55.629306
# r9inv_zip5         27.021113
# r1_zip3             0.001439
# r2_zip3             0.471301
# r3_zip3             0.377536
# r4_zip3             0.036227
# r5_zip3             0.058401
# r6_zip3             0.061972
# r7_zip3             0.078354
# r8_zip3             0.044381
# r9_zip3             0.061303
# r1inv_zip3          0.022610
# r2inv_zip3          3.870455
# r3inv_zip3          2.037290
# r4inv_zip3          0.018976
# r5inv_zip3         38.024281
# r6inv_zip3         16.698718
# r7inv_zip3          0.015147
# r8inv_zip3         21.262430
# r9inv_zip3         15.788793
# r1_taxclass         0.113262
# r2_taxclass         0.267611
# r3_taxclass         0.287236
# r4_taxclass         0.058502
# r5_taxclass         0.155182
# r6_taxclass         0.158389
# r7_taxclass         0.016790
# r8_taxclass         0.163024
# r9_taxclass         0.177677
# r1inv_taxclass      0.002003
# r2inv_taxclass    648.455279
# r3inv_taxclass    753.597262
# r4inv_taxclass      0.031215
# r5inv_taxclass    586.352291
# r6inv_taxclass    657.333470
# r7inv_taxclass      0.015738
# r8inv_taxclass    625.536220
# r9inv_taxclass    736.753067
# r1_boro             0.001460
# r2_boro             0.499426
# r3_boro             0.393327
# r4_boro             0.036713
# r5_boro             0.058314
# r6_boro             0.062332
# r7_boro             0.078732
# r8_boro             0.045593
# r9_boro             0.063583
# r1inv_boro          0.016882
# r2inv_boro          2.986507
# r3inv_boro          1.502301
# r4inv_boro          0.018495
# r5inv_boro         31.202957
# r6inv_boro         13.801822
# r7inv_boro          0.015106
# r8inv_boro         21.267255
# r9inv_boro         15.682684
# Name: 956520, dtype: float64
# BBLE                  5006590012
# BORO                           5
# BLOCK                        659
# LOT                           12
# EASEMENT                     NaN
# OWNER          TROMPETA RIZALINA
# BLDGCL                        A1
# TAXCLASS                       1
# LTFRONT                       25
# LTDEPTH                       91
# EXT                            G
# STORIES                      3.0
# FULLVAL                 348200.0
# AVLAND                   15600.0
# AVTOT                    20892.0
# EXLAND                    1620.0
# EXTOT                     1620.0
# EXCD1                     1017.0
# STADDR          12 ONEIDA AVENUE
# ZIP                      10301.0
# EXMPTCL                      NaN
# BLDFRONT                    1812
# BLDDEPTH                    5020
# AVLAND2                      NaN
# AVTOT2                       NaN
# EXLAND2                      NaN
# EXTOT2                       NaN
# EXCD2                        NaN
# PERIOD                     FINAL
# YEAR                     2010/11
# VALTYPE                    AC-TR
# score1 rank            1046823.0
# score2 rank            1046798.0
# final                  1046810.5
# Name: 956520, dtype: object

# %%
record_inv = 47984
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
NY_data_with_scores.loc[record_inv]
# Out:
# r1                132.483000
# r2                 68.356898
# r3                 70.446893
# r4                 80.647544
# r5                 14.876969
# r6                 15.796018
# r7                156.073553
# r8                 34.108229
# r9                 48.632561
# r1inv               0.019486
# r2inv               0.025087
# r3inv               0.027989
# r4inv               0.014906
# r5inv               0.046387
# r6inv               0.034105
# r7inv               0.004790
# r8inv               0.039185
# r9inv               0.041718
# r1_zip5            92.399157
# r2_zip5            74.075894
# r3_zip5           142.058580
# r4_zip5            25.493150
# r5_zip5            12.122727
# r6_zip5            19.423144
# r7_zip5            42.899065
# r8_zip5            27.095363
# r9_zip5            66.288861
# r1inv_zip5          0.049761
# r2inv_zip5          0.060935
# r3inv_zip5          0.055447
# r4inv_zip5          0.070266
# r5inv_zip5          0.075568
# r6inv_zip5          0.068984
# r7inv_zip5          0.055558
# r8inv_zip5          0.055423
# r9inv_zip5          0.053172
# r1_zip3            79.548608
# r2_zip3            62.396681
# r3_zip3           116.365509
# r4_zip3            25.304072
# r5_zip3             6.650212
# r6_zip3            16.083315
# r7_zip3            45.295558
# r8_zip3            10.644516
# r9_zip3            43.175480
# r1inv_zip3          0.023392
# r2inv_zip3          0.029015
# r3inv_zip3          0.028378
# r4inv_zip3          0.020155
# r5inv_zip3          0.062198
# r6inv_zip3          0.041138
# r7inv_zip3          0.016005
# r8inv_zip3          0.040380
# r9inv_zip3          0.046598
# r1_taxclass        92.158151
# r2_taxclass        47.756632
# r3_taxclass        68.811506
# r4_taxclass        38.690337
# r5_taxclass        11.015162
# r6_taxclass        12.566841
# r7_taxclass        90.617142
# r8_taxclass        27.727032
# r9_taxclass        40.774342
# r1inv_taxclass      0.069121
# r2inv_taxclass      0.045726
# r3inv_taxclass      0.036953
# r4inv_taxclass      0.077331
# r5inv_taxclass      0.072967
# r6inv_taxclass      0.057704
# r7inv_taxclass      0.064076
# r8inv_taxclass      0.060386
# r9inv_taxclass      0.049729
# r1_boro            82.842318
# r2_boro            67.745304
# r3_boro           123.975299
# r4_boro            26.617719
# r5_boro             6.884232
# r6_boro            16.807660
# r7_boro            46.991762
# r8_boro            11.297897
# r9_boro            46.419417
# r1inv_boro          0.017466
# r2inv_boro          0.022388
# r3inv_boro          0.020926
# r4inv_boro          0.019645
# r5inv_boro          0.051040
# r6inv_boro          0.034001
# r7inv_boro          0.015962
# r8inv_boro          0.040389
# r9inv_boro          0.046285
# Name: 47984, dtype: float64
# BBLE                      1008800024
# BORO                               1
# BLOCK                            880
# LOT                               24
# EASEMENT                         NaN
# OWNER          BERKOWTIZ, ULWT LOUIS
# BLDGCL                            W6
# TAXCLASS                           4
# LTFRONT                           39
# LTDEPTH                           50
# EXT                              NaN
# STORIES                          2.0
# FULLVAL                  138000000.0
# AVLAND                    11025000.0
# AVTOT                     62100000.0
# EXLAND                    11025000.0
# EXTOT                     62100000.0
# EXCD1                         3500.0
# STADDR           49 LEXINGTON AVENUE
# ZIP                          10010.0
# EXMPTCL                          NaN
# BLDFRONT                          39
# BLDDEPTH                          50
# AVLAND2                    9415800.0
# AVTOT2                    56239200.0
# EXLAND2                    9415800.0
# EXTOT2                    56239200.0
# EXCD2                            NaN
# PERIOD                         FINAL
# YEAR                         2010/11
# VALTYPE                        AC-TR
# score1 rank                1046778.0
# score2 rank                1046423.0
# final                      1046600.5
# Name: 47984, dtype: object

# %%
record_inv = 235407
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
# NY_data_with_scores.loc[record_inv].to_csv('~/Downloads/235407.csv')
# Out:
# r1                37.270150
# r2                 0.002430
# r3                 0.309255
# r4                 8.144368
# r5                 0.019093
# r6                 0.041738
# r7                44.150845
# r8                 0.206016
# r9                 0.065269
# r1inv              0.019480
# r2inv              0.024483
# r3inv              0.027614
# r4inv              0.014894
# r5inv              0.043559
# r6inv              0.033109
# r7inv              0.004789
# r8inv              0.038723
# r9inv              0.041299
# r1_zip5           56.861378
# r2_zip5            0.120547
# r3_zip5            0.221606
# r4_zip5           14.675316
# r5_zip5            0.057388
# r6_zip5            0.084469
# r7_zip5           49.024242
# r8_zip5            0.370618
# r9_zip5            0.035815
# r1inv_zip5         0.049709
# r2inv_zip5         0.059374
# r3inv_zip5         0.053809
# r4inv_zip5         0.069947
# r5inv_zip5         0.061327
# r6inv_zip5         0.050737
# r7inv_zip5         0.055549
# r8inv_zip5         0.054705
# r9inv_zip5         0.052236
# r1_zip3           57.717534
# r2_zip3            0.147224
# r3_zip3            0.210196
# r4_zip3           14.905888
# r5_zip3            0.006967
# r6_zip3            0.046063
# r7_zip3           75.248322
# r8_zip3            0.226634
# r9_zip3            0.065989
# r1inv_zip3         0.023382
# r2inv_zip3         0.027953
# r3inv_zip3         0.027536
# r4inv_zip3         0.020131
# r5inv_zip3         0.056440
# r6inv_zip3         0.037287
# r7inv_zip3         0.016003
# r8inv_zip3         0.039935
# r9inv_zip3         0.045961
# r1_taxclass       25.880911
# r2_taxclass        0.098082
# r3_taxclass        0.111850
# r4_taxclass        3.700943
# r5_taxclass        0.124396
# r6_taxclass        0.146704
# r7_taxclass       25.446286
# r8_taxclass        0.049348
# r9_taxclass        0.073736
# r1inv_taxclass     0.069117
# r2inv_taxclass     0.045552
# r3inv_taxclass     0.036857
# r4inv_taxclass     0.077314
# r5inv_taxclass     0.071785
# r6inv_taxclass     0.057380
# r7inv_taxclass     0.064071
# r8inv_taxclass     0.060140
# r9inv_taxclass     0.049594
# r1_boro           58.620534
# r2_boro            0.156295
# r3_boro            0.219007
# r4_boro           15.132608
# r5_boro            0.006948
# r6_boro            0.046332
# r7_boro           75.740362
# r8_boro            0.232976
# r9_boro            0.068501
# r1inv_boro         0.017458
# r2inv_boro         0.021570
# r3inv_boro         0.020306
# r4inv_boro         0.019621
# r5inv_boro         0.046323
# r6inv_boro         0.030825
# r7inv_boro         0.015959
# r8inv_boro         0.039946
# r9inv_boro         0.045654
# Name: 235407, dtype: float64

# %%
data_zs_top_n_abs.shape
# Out:
# (1000, 90)

# %%
cnt = 0
for i in data_zs_top_n_abs.index:
    if (data_zs_top_n_abs.loc[i, ['r1','r2','r3']] > 10).all():
        print(i)
        cnt+=1
print(cnt)
# Out:
# 47984
# 309177
# 2
# 748183
# 97076
# 5

# %%
record_inv = 116647
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
NY_data_with_scores.loc[record_inv]
# Out:
# r1                160.831592
# r2                  4.387050
# r3                  0.200415
# r4                146.300951
# r5                  1.530111
# r6                  0.040139
# r7                189.397323
# r8                  2.380685
# r9                  0.139976
# r1inv               0.019487
# r2inv               0.025027
# r3inv               0.027755
# r4inv               0.014907
# r5inv               0.046321
# r6inv               0.033955
# r7inv               0.004790
# r8inv               0.039138
# r9inv               0.041457
# r1_zip5           110.957867
# r2_zip5             4.127580
# r3_zip5             0.074067
# r4_zip5            77.338636
# r5_zip5             1.977195
# r6_zip5             0.118815
# r7_zip5            86.677632
# r8_zip5             3.070078
# r9_zip5             0.358084
# r1inv_zip5          0.049772
# r2inv_zip5          0.060901
# r3inv_zip5          0.055358
# r4inv_zip5          0.070283
# r5inv_zip5          0.075550
# r6inv_zip5          0.068921
# r7inv_zip5          0.055570
# r8inv_zip5          0.055391
# r9inv_zip5          0.053087
# r1_zip3            99.965993
# r2_zip3             4.146589
# r3_zip3             0.076338
# r4_zip3            61.932747
# r5_zip3             0.942291
# r6_zip3             0.073744
# r7_zip3            68.780861
# r8_zip3             1.002887
# r9_zip3             0.173737
# r1inv_zip3          0.023393
# r2inv_zip3          0.028992
# r3inv_zip3          0.028332
# r4inv_zip3          0.020156
# r5inv_zip3          0.062168
# r6inv_zip3          0.041100
# r7inv_zip3          0.016006
# r8inv_zip3          0.040349
# r9inv_zip3          0.046523
# r1_taxclass       346.523125
# r2_taxclass        11.173857
# r3_taxclass         2.006068
# r4_taxclass       328.973620
# r5_taxclass         6.862436
# r6_taxclass         1.156481
# r7_taxclass       343.358827
# r8_taxclass         6.807006
# r9_taxclass         1.240906
# r1inv_taxclass      0.069120
# r2inv_taxclass      0.045671
# r3inv_taxclass      0.036847
# r4inv_taxclass      0.077331
# r5inv_taxclass      0.072918
# r6inv_taxclass      0.057605
# r7inv_taxclass      0.064075
# r8inv_taxclass      0.060309
# r9inv_taxclass      0.049581
# r1_boro           100.605515
# r2_boro             4.364470
# r3_boro             0.113167
# r4_boro            48.375316
# r5_boro             0.680864
# r6_boro             0.040303
# r7_boro            57.045988
# r8_boro             0.762877
# r9_boro             0.125725
# r1inv_boro          0.017466
# r2inv_boro          0.022361
# r3inv_boro          0.020879
# r4inv_boro          0.019645
# r5inv_boro          0.051006
# r6inv_boro          0.033960
# r7inv_boro          0.015962
# r8inv_boro          0.040338
# r9inv_boro          0.046179
# Name: 116647, dtype: float64
# BBLE                     1015410021
# BORO                              1
# BLOCK                          1541
# LOT                              21
# EASEMENT                        NaN
# OWNER          MF ASSOCIATES OF NEW
# BLDGCL                           D6
# TAXCLASS                          2
# LTFRONT                          25
# LTDEPTH                          75
# EXT                             NaN
# STORIES                        35.0
# FULLVAL                 161000000.0
# AVLAND                   19215000.0
# AVTOT                    72450000.0
# EXLAND                          0.0
# EXTOT                           0.0
# EXCD1                           NaN
# STADDR                1849 2 AVENUE
# ZIP                         10128.0
# EXMPTCL                         NaN
# BLDFRONT                         70
# BLDDEPTH                        456
# AVLAND2                  19215000.0
# AVTOT2                   66960000.0
# EXLAND2                         NaN
# EXTOT2                          NaN
# EXCD2                           NaN
# PERIOD                        FINAL
# YEAR                        2010/11
# VALTYPE                       AC-TR
# score1 rank               1046789.0
# score2 rank               1046515.0
# final                     1046652.0
# Name: 116647, dtype: object

# %% [markdown]
# ____

# %%
record_inv = 111420
with pd.option_context('display.max_rows', None):
    display(data_zs_top_n_abs.loc[record_inv])
NY_data_with_scores.loc[record_inv]
# Out:
# r1                  0.321199
# r2                  0.522084
# r3                  0.489316
# r4                  0.102637
# r5                  0.060280
# r6                  0.056308
# r7                  0.037787
# r8                  0.054130
# r9                  0.058326
# r1inv               0.015437
# r2inv              78.691122
# r3inv             251.532644
# r4inv               0.012427
# r5inv             137.338616
# r6inv             249.306906
# r7inv               0.004347
# r8inv              60.152932
# r9inv             280.601668
# r1_zip5             0.426677
# r2_zip5             0.469001
# r3_zip5             0.366533
# r4_zip5             0.180747
# r5_zip5             0.122415
# r6_zip5             0.099852
# r7_zip5             0.145980
# r8_zip5             0.135722
# r9_zip5             0.126347
# r1inv_zip5          0.040810
# r2inv_zip5         96.930662
# r3inv_zip5        120.769262
# r4inv_zip5          0.055616
# r5inv_zip5        129.450464
# r6inv_zip5        155.603819
# r7inv_zip5          0.045602
# r8inv_zip5         87.979551
# r9inv_zip5        115.768158
# r1_zip3             0.368652
# r2_zip3             0.471335
# r3_zip3             0.377554
# r4_zip3             0.141628
# r5_zip3             0.058406
# r6_zip3             0.061975
# r7_zip3             0.109473
# r8_zip3             0.044383
# r9_zip3             0.061305
# r1inv_zip3          0.021072
# r2inv_zip3         46.232183
# r3inv_zip3         68.114004
# r4inv_zip3          0.018261
# r5inv_zip3         86.211474
# r6inv_zip3         82.860132
# r7inv_zip3          0.014344
# r8inv_zip3         67.479422
# r9inv_zip3        115.685334
# r1_taxclass         0.170100
# r2_taxclass         0.267617
# r3_taxclass         0.287245
# r4_taxclass         0.196155
# r5_taxclass         0.155193
# r6_taxclass         0.158399
# r7_taxclass         0.168549
# r8_taxclass         0.163031
# r9_taxclass         0.177685
# r1inv_taxclass      0.063525
# r2inv_taxclass     68.303322
# r3inv_taxclass    113.132773
# r4inv_taxclass      0.070908
# r5inv_taxclass     97.126185
# r6inv_taxclass    163.605465
# r7inv_taxclass      0.058653
# r8inv_taxclass     95.077732
# r9inv_taxclass    159.382621
# r1_boro             0.372649
# r2_boro             0.499463
# r3_boro             0.393347
# r4_boro             0.142963
# r5_boro             0.058319
# r6_boro             0.062335
# r7_boro             0.109113
# r8_boro             0.045595
# r9_boro             0.063585
# r1inv_boro          0.015745
# r2inv_boro         35.520584
# r3inv_boro         50.093666
# r4inv_boro          0.017805
# r5inv_boro         71.182804
# r6inv_boro         68.646748
# r7inv_boro          0.014322
# r8inv_boro         66.964902
# r9inv_boro        114.318045
# Name: 111420, dtype: float64
# BBLE                      1015101092
# BORO                               1
# BLOCK                           1510
# LOT                             1092
# EASEMENT                         NaN
# OWNER          BOXWOOD FLTD PARNTERS
# BLDGCL                            R4
# TAXCLASS                           2
# LTFRONT                           75
# LTDEPTH                           93
# EXT                              NaN
# STORIES                         31.0
# FULLVAL                     296508.0
# AVLAND                       22896.0
# AVTOT                       133429.0
# EXLAND                           0.0
# EXTOT                            0.0
# EXCD1                            NaN
# STADDR                 1438 3 AVENUE
# ZIP                          10028.0
# EXMPTCL                          NaN
# BLDFRONT                        7575
# BLDDEPTH                        9393
# AVLAND2                      22896.0
# AVTOT2                      146183.0
# EXLAND2                          NaN
# EXTOT2                           NaN
# EXCD2                            NaN
# PERIOD                         FINAL
# YEAR                         2010/11
# VALTYPE                        AC-TR
# score1 rank                1046793.0
# score2 rank                1046719.0
# final                      1046756.0
# Name: 111420, dtype: object
